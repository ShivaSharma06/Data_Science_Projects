# %% [markdown]
# # Web Scrapping

# %%
import bs4
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import nltk
import numpy as np
import re
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from textblob import TextBlob
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.cluster import KMeans
import pandas as pd
from datetime import datetime
from dateutil.relativedelta import relativedelta
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Phase 1

# %%
df = pd.read_csv('Flipkart - Redgear Gamepad.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0                Name           Date  Rating  Images  Likes  \
# 0           0  soumyadeep  sharma      Feb, 2019       5       5    518
# 1           1         Krishna Rao      Aug, 2016       5       0    106
# 2           2        Chanchal Pan      Dec, 2018       5       1     44
# 3           3      abhishek kumar      Jun, 2016       5       0    248
# 4           4   YUSUF RASOOL KHAN      Jul, 2021       5       1     27
# 5           5       Reena  Rajput      Feb, 2019       5       1     12
# 6           6   Flipkart Customer  11 months ago       5       1     18
# 7           7   Flipkart Customer      Oct, 2021       5       0     17
# 8           8         taha  Adnan      Dec, 2018       5       1    117
# 9           9      Nilesh Talekar      May, 2020       5       1     17
#
#    Dislikes            Review Title  \
# 0        78      Highly recommended
# 1        15  Coolest piece ever had
# 2         4           Great product
# 3        49           LIKE XBOX 360
# 4         2                  Super!
# 5         0                  Super!
# 6         1                Terrific
# 7         1               Excellent
# 8        26                Terrific
# 9         1   Mind-blowing purchase
#
#                                          Review Text  \
# 0  great product ... love it ... my favorite game...
# 1           Very good product, must have for gamers.
# 2                                               best
# 3  At first time i got a defective piece it's rec...
# 4  Very nice game pet, runs very smooth thank you...
# 5                                          Awesome 👌
# 6  Amazing product I love it vibration is very go...
# 7  Yes. It works with Android TV and I know that ...
# 8  Better than many other pricy gamepad..... Grea...
# 9  i've been using this controller since 2 yearsi...
#
#                               location
# 0  North Twenty Four Parganas District
# 1                            Bangalore
# 2                              Burdwan
# 3                                Patna
# 4                               Nagpur
# 5                                Jammu
# 6                               Rohtak
# 7                            New Delhi
# 8                             Warangal
# 9                           Aurangabad

# %%
# Drop the column 'Unnamed: 0'
df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
df.describe()
# Out:
#             Rating       Images        Likes     Dislikes
# count  2380.000000  2380.000000  2380.000000  2380.000000
# mean      4.348319     0.114286     1.230672     0.410504
# std       1.172446     0.471515    18.091407     4.646293
# min       1.000000     0.000000     0.000000     0.000000
# 25%       4.000000     0.000000     0.000000     0.000000
# 50%       5.000000     0.000000     0.000000     0.000000
# 75%       5.000000     0.000000     0.000000     0.000000
# max       5.000000     5.000000   622.000000   184.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2380 entries, 0 to 2379
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          2380 non-null   object
#  1   Date          2380 non-null   object
#  2   Rating        2380 non-null   int64
#  3   Images        2380 non-null   int64
#  4   Likes         2380 non-null   int64
#  5   Dislikes      2380 non-null   int64
#  6   Review Title  2380 non-null   object
#  7   Review Text   2380 non-null   object
#  8   location      2380 non-null   object
# dtypes: int64(4), object(5)
# memory usage: 167.5+ KB

# %%
df.Rating.value_counts()
# Out:
# 5    1597
# 4     429
# 1     183
# 3     123
# 2      48
# Name: Rating, dtype: int64

# %%
#Preprocessing

stop_words = nltk.corpus.stopwords.words('english')

def normalize_document(doc):
    # lower case and remove special characters\whitespaces
    doc = re.sub(r'[^a-zA-Z0-9\s]', '', doc) #remove any characters that are not alphanumeric or whitespace
    doc = doc.lower() #lowercase
    doc = doc.strip() #Removes leading and trailing whitespaces
    tokens = nltk.word_tokenize(doc) #Tokenizes the document into individual words
    filtered_tokens = [token for token in tokens if token not in stop_words] #Filters out stopwords
    doc = ' '.join(filtered_tokens) #Reconstructs the document from the filtered tokens by joining them back into a single string separated by spaces
    return doc

normalize_corpus = np.vectorize(normalize_document) #Vectorizes the normalize_document function

norm_corpus = normalize_corpus(list(df['Review Text'])) # applying function to dataframe, producing a normalized corpus of documents
norm_corpus
# Out:
# array(['great product love favorite gamepad beautiful smooth',
#        'good product must gamers', 'best', ...,
#        'good gamepad reasonable pricebut issues charging1 charged gamepad 4 hours unplugged charger play fifa fifteen minutes indicator shows low batteryi hope fixedotherwise classa gamepad',
#        'brought controller usb dongle isnt working properlynow completely stopped working wit response wen put usb jacky flikart sale duplicate stuff',
#        'see theres 10days replacement guarantee took 13 days malfunction wan na throw away money cheap controller lasts barely two weeks go'],
#       dtype='<U383')

# %%
#convert a collection of text documents (norm_corpus) into a matrix of token counts

cv = CountVectorizer(ngram_range=(1, 2), min_df=20, max_df=0.8) #both single words and pairs of consecutive words. Tokens that occur in fewer than 20 documents will be ignored. Tokens that occur in more than 80% of the documents will be ignored.
cv_matrix = cv.fit_transform(norm_corpus) #transforms the corpus into a document-term matrix. The value at the intersection of a row and column represents the count of how many times that word or n-gram appears in the corresponding document.
cv_matrix.shape #(n_documents, n_features). n_documents represents the number of documents in the corpus, and n_features represents the number of unique words and n-grams in the vocabulary.
# Out:
# (2380, 206)

# %%
sentiments = []
for text in norm_corpus:
    blob = TextBlob(text)
    sentiment_score = blob.sentiment.polarity
    if sentiment_score > 0:
        sentiments.append('Positive')
    elif sentiment_score < 0:
        sentiments.append('Negative')
    else:
        sentiments.append('Neutral')

# Add sentiment labels to DataFrame
df['Sentiment'] = sentiments

# Display the DataFrame with sentiment labels
print(df[['Review Text', 'Sentiment']])
# Out:
#                                             Review Text Sentiment
# 0     great product ... love it ... my favorite game...  Positive
# 1              Very good product, must have for gamers.  Positive
# 2                                                  best  Positive
# 3     At first time i got a defective piece it's rec...  Positive
# 4     Very nice game pet, runs very smooth thank you...  Positive
# ...                                                 ...       ...
# 2375  Its first time I'm using gamepad... Its very g...  Positive
# 2376  Luckily they were nice enough to replace my co...  Positive
# 2377  Its a very good gamepad at a very reasonable p...  Positive
# 2378  Brought this controller but the usb dongle isn...  Positive
# 2379  I can see why there's only 10-days replacement...  Positive
#
# [2380 rows x 2 columns]

# %%
df.head(30)
# Out:
#                     Name           Date  Rating  Images  Likes  Dislikes  \
# 0     soumyadeep  sharma      Feb, 2019       5       5    518        78
# 1            Krishna Rao      Aug, 2016       5       0    106        15
# 2           Chanchal Pan      Dec, 2018       5       1     44         4
# 3         abhishek kumar      Jun, 2016       5       0    248        49
# 4      YUSUF RASOOL KHAN      Jul, 2021       5       1     27         2
# 5          Reena  Rajput      Feb, 2019       5       1     12         0
# 6      Flipkart Customer  11 months ago       5       1     18         1
# 7      Flipkart Customer      Oct, 2021       5       0     17         1
# 8            taha  Adnan      Dec, 2018       5       1    117        26
# 9         Nilesh Talekar      May, 2020       5       1     17         1
# 10               sagar R      Jan, 2017       5       0    622       184
# 11        Gayatri Patley      Dec, 2018       5       5     43         7
# 12       Hrishabh  Gupta      Oct, 2019       5       3     61        15
# 13     Flipkart Customer      May, 2019       5       1     20         3
# 14     Nishant Chaudhary      Sep, 2018       5       1     15         2
# 15         Biplab Sikder      Aug, 2018       5       3     18         3
# 16    Tarun Anand Mishra      Apr, 2019       5       2      7         0
# 17         Nikhil Matade      Apr, 2019       4       1      7         0
# 18           Suraj Kumar      Jul, 2018       5       1      7         0
# 19     Jaideep  Khedekar      May, 2018       5       1     39        12
# 20         Aakash Satija      Jul, 2016       5       0    128        56
# 21           SAGIR  AHMD      Apr, 2022       5       1      8         1
# 22  Agniprovo pattanayak      Dec, 2017       5       3      6         0
# 23            lalit Soni      Jun, 2021       4       2     13         2
# 24         Yagnesh Patel      May, 2017       5       0     11         2
# 25          Devansh Aman      Jul, 2022       1       0      6         0
# 26      Mayank K Dwivedi      Dec, 2021       5       2      6         0
# 27           Vikas Samal      May, 2018       5       3     63        26
# 28           Sumit Patra      Oct, 2018       5       1      6         0
# 29             Meet Vyas      Nov, 2019       5       1     15         4
#
#                      Review Title  \
# 0              Highly recommended
# 1          Coolest piece ever had
# 2                   Great product
# 3                   LIKE XBOX 360
# 4                          Super!
# 5                          Super!
# 6                        Terrific
# 7                       Excellent
# 8                        Terrific
# 9           Mind-blowing purchase
# 10          Gear up with RED gear
# 11                        Awesome
# 12  Best In Class In Every Aspect
# 13              Terrific purchase
# 14               Perfect product!
# 15                        Awesome
# 16            Best in the market!
# 17                    Good choice
# 18              Terrific purchase
# 19          Mind-blowing purchase
# 20   Has everything that you need
# 21                      Brilliant
# 22                  Great product
# 23                   Nice product
# 24             Highly recommended
# 25      Did not meet expectations
# 26                 Simply awesome
# 27              Terrific purchase
# 28              Worth every penny
# 29                         Super!
#
#                                           Review Text  \
# 0   great product ... love it ... my favorite game...
# 1            Very good product, must have for gamers.
# 2                                                best
# 3   At first time i got a defective piece it's rec...
# 4   Very nice game pet, runs very smooth thank you...
# 5                                           Awesome 👌
# 6   Amazing product I love it vibration is very go...
# 7   Yes. It works with Android TV and I know that ...
# 8   Better than many other pricy gamepad..... Grea...
# 9   i've been using this controller since 2 yearsi...
# 10  This product was a Gift and I tested everythin...
# 11  This product is very good we can play all game...
# 12  Well, It has very ergonomic and strong build q...
# 13  wow build quality is very nice support all gam...
# 14  got delivered in just 2 days, no issues with p...
# 15  it's compatible. This is what I'm doing with m...
# 16                                            Awesome
# 17  one of the best controller among all prices! I...
# 18                         Awsm product!!  Must buy💗💗
# 19  works like charm , could not get any better fo...
# 20  You plug this in. It instantly works. And you ...
# 21  Nice and amazing feeling in hands with this pr...
# 22  I have been using this product for 1 year but ...
# 23  It was great 😊 price little bit high but it's ...
# 24  Awesome Product I am writing this after 1 mont...
# 25  I don't know why people send used and old prod...
# 26  Really a very good remote in this price, price...
# 27  It is one of the best consoles ever.Forget abo...
# 28                       Mind blowing. Super product.
# 29  I bought this in January 2017 and is still wor...
#
#                                location Sentiment
# 0   North Twenty Four Parganas District  Positive
# 1                             Bangalore  Positive
# 2                               Burdwan  Positive
# 3                                 Patna  Positive
# 4                                Nagpur  Positive
# 5                                 Jammu  Positive
# 6                                Rohtak  Positive
# 7                             New Delhi  Positive
# 8                              Warangal  Positive
# 9                            Aurangabad  Positive
# 10                           Aurangabad  Positive
# 11                     Raigarh District  Positive
# 12                               Kanpur  Positive
# 13                Thoothukkudi District  Positive
# 14                              Jalgaon   Neutral
# 15                  Nebadhai Duttapukur   Neutral
# 16                            New Delhi  Positive
# 17                                Hubli  Positive
# 18                      Rajpur Sonarpur   Neutral
# 19                           Aurangabad  Positive
# 20                            New Delhi  Positive
# 21                                  Nuh  Positive
# 22                             Panskura  Positive
# 23                            New Delhi  Positive
# 24                               Rajkot  Positive
# 25                       Solan District  Negative
# 26                               Indore  Positive
# 27                          Bhubaneswar  Positive
# 28                     Bankura District  Positive
# 29                                Thane  Positive

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2380 entries, 0 to 2379
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          2380 non-null   object
#  1   Date          2380 non-null   object
#  2   Rating        2380 non-null   int64
#  3   Images        2380 non-null   int64
#  4   Likes         2380 non-null   int64
#  5   Dislikes      2380 non-null   int64
#  6   Review Title  2380 non-null   object
#  7   Review Text   2380 non-null   object
#  8   location      2380 non-null   object
#  9   Sentiment     2380 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 186.1+ KB

# %%
sentiment_counts = df['Sentiment'].value_counts()
sentiment_counts
# Out:
# Positive    1984
# Neutral      267
# Negative     129
# Name: Sentiment, dtype: int64

# %% [markdown]
# **Positive Sentiment (1838 reviews):**
#
# High positive sentiment indicates that a significant portion of customers are satisfied with the product.
# Businesses can use positive reviews for marketing purposes, such as testimonials on their website or social media channels.
# It suggests that the product is meeting customer expectations and may lead to repeat purchases and positive word-of-mouth recommendations.
#
# **Neutral Sentiment (247 reviews):**
#
# Neutral sentiment could indicate a mixed reception from customers.
# Businesses should investigate further to understand the reasons behind the neutral sentiment. It could be due to minor issues or areas where the product can be improved.
# Neutral sentiment reviews provide an opportunity for businesses to gather constructive feedback and make necessary adjustments to enhance customer satisfaction.
#
# **Negative Sentiment (115 reviews):**
#
# Negative sentiment reviews highlight areas of dissatisfaction or issues with the product.
# Businesses should prioritize addressing the concerns raised in negative reviews to improve customer experience and prevent further negative feedback.
# Negative reviews can also be an opportunity for businesses to demonstrate their commitment to customer satisfaction by addressing issues promptly and transparently.

# %%
# Filter positive sentiment reviews
positive_reviews_df = df[df['Sentiment'] == 'Positive']

# %%
# Tokenize and preprocess positive sentiment reviews
positive_norm_corpus = normalize_corpus(positive_reviews_df['Review Text'])

# %%
# Vectorize text using TF-IDF
tfidf_vectorizer = TfidfVectorizer(max_features=1000, max_df=0.8, min_df=20)
tfidf_matrix = tfidf_vectorizer.fit_transform(positive_norm_corpus)

# %%
# Apply Latent Dirichlet Allocation (LDA) for topic modeling
num_topics = 10  # You can adjust the number of topics as needed
lda_model = LatentDirichletAllocation(n_components=num_topics, random_state=42)
lda_topic_matrix = lda_model.fit_transform(tfidf_matrix)

# %%
# Display topics and associated top words
feature_names = tfidf_vectorizer.get_feature_names_out()
for topic_idx, topic in enumerate(lda_model.components_):
    print(f"Topic {topic_idx+1}:")
    top_words_idx = topic.argsort()[:-10 - 1:-1]
    top_words = [feature_names[i] for i in top_words_idx]
    print(top_words)
# Out:
# Topic 1:
# ['amazing', 'android', 'tv', 'game', 'works', 'product', 'pad', 'games', 'bought', 'awesome']
# Topic 2:
# ['nice', 'product', 'love', 'gamepad', 'little', 'must', 'bit', 'cheap', 'buy', 'price']
# Topic 3:
# ['best', 'controller', 'gamepad', 'price', 'range', 'budget', 'ever', 'pc', 'go', 'gamers']
# Topic 4:
# ['good', 'battery', 'better', 'playing', 'life', 'gamepad', 'using', 'controller', 'feel', 'months']
# Topic 5:
# ['worth', 'money', 'product', 'delivery', 'good', 'flipkart', 'value', 'happy', 'buy', 'dont']
# Topic 6:
# ['one', 'work', 'good', 'satisfied', 'time', 'response', 'get', 'first', 'controller', 'cant']
# Topic 7:
# ['great', 'superb', 'gaming', 'experience', 'product', 'vibration', 'controller', 'battery', 'backup', 'good']
# Topic 8:
# ['good', 'product', 'awesome', 'price', 'loved', 'gamepad', 'really', 'range', 'go', 'got']
# Topic 9:
# ['excellent', 'quality', 'super', 'good', 'working', 'perfect', 'product', 'build', 'fine', 'recommend']
# Topic 10:
# ['smooth', 'easy', 'good', 'thanks', 'well', 'use', 'also', 'play', 'buttons', 'flipkart']

# %% [markdown]
# **Product Performance and Functionality (Topics 1, 4, 7, 10):**
#
# Customers appreciate the performance of the gamepad, including its compatibility with various devices (Android TV, PC), responsiveness, smoothness, and ease of use.
# Implication: Businesses should focus on maintaining or improving the product's performance and functionality to meet customer expectations consistently. This may involve optimizing compatibility, enhancing battery life, and ensuring smooth gameplay experience.
#
# **Value for Money (Topics 2, 5, 8):**
#
# Positive reviews mention the product's affordability, value for money, and satisfaction with the purchase.
# Implication: Businesses can emphasize the product's competitive pricing and value proposition in marketing campaigns to attract price-conscious customers. Offering discounts, promotions, or bundle deals may further enhance the perceived value of the product.
#
# **Quality and Durability (Topics 3, 9):**
#
# Customers praise the gamepad's build quality, durability, and overall performance, considering it among the best in its price range.
# Implication: Businesses should prioritize maintaining product quality and durability standards to sustain positive customer sentiment and loyalty. Investing in high-quality materials, rigorous testing, and continuous improvement processes can contribute to long-term customer satisfaction.
#
# **Customer Experience and Service (Topics 6):**
#
# Positive reviews highlight satisfactory customer experiences, including prompt delivery, responsive customer service, and overall satisfaction with the purchase.
# Implication: Businesses should prioritize providing excellent customer service, ensuring timely delivery, and addressing any issues or concerns promptly. Positive customer experiences contribute to brand loyalty and positive word-of-mouth referrals, driving future sales and customer retention.
#
# **Feedback for Improvement (All Topics):**
#
# While positive reviews generally reflect satisfaction with the product, they may also contain suggestions for improvement or feature requests.
# Implication: Businesses should actively monitor and analyze customer feedback, both positive and negative, to identify areas for product enhancement or new feature development. Incorporating customer feedback into product development processes demonstrates a commitment to continuous improvement and customer-centric innovation.

# %%
# Perform KMeans clustering
num_clusters = 3  # You can adjust the number of clusters as needed
kmeans_model = KMeans(n_clusters=num_clusters, random_state=42)
kmeans_clusters = kmeans_model.fit_predict(tfidf_matrix)
# Out:
# C:\Users\Shreyas\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Add cluster labels to the DataFrame
positive_reviews_df['Cluster'] = kmeans_clusters
# Out:
# C:\Users\Shreyas\AppData\Local\Temp\ipykernel_37920\3589983744.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   positive_reviews_df['Cluster'] = kmeans_clusters

# %%
# Display the DataFrame with cluster labels
print(positive_reviews_df[['Review Text', 'Cluster']])
# Out:
#                                             Review Text  Cluster
# 0     great product ... love it ... my favorite game...        0
# 1              Very good product, must have for gamers.        0
# 2                                                  best        0
# 3     At first time i got a defective piece it's rec...        0
# 4     Very nice game pet, runs very smooth thank you...        1
# ...                                                 ...      ...
# 2375  Its first time I'm using gamepad... Its very g...        0
# 2376  Luckily they were nice enough to replace my co...        0
# 2377  Its a very good gamepad at a very reasonable p...        0
# 2378  Brought this controller but the usb dongle isn...        0
# 2379  I can see why there's only 10-days replacement...        0
#
# [1984 rows x 2 columns]

# %%
Cluster_counts = positive_reviews_df['Cluster'].value_counts()
Cluster_counts
# Out:
# 0    1542
# 2     252
# 1     190
# Name: Cluster, dtype: int64

# %% [markdown]
# **Understanding Customer Segments:**
#
# The clustering results indicate that there are at least three distinct segments of customers who perceive the product positively.
# Implication: Businesses should conduct further analysis to understand the characteristics and preferences of each customer segment. This information can help tailor marketing strategies, product features, and customer support to better meet the needs of each segment.
#
# **Identifying Key Features or Benefits:**
#
# Each cluster may represent customers who prioritize different features or benefits of the product.
# Implication: By analyzing the characteristics of each cluster and the most common terms or topics within each cluster, businesses can identify key features or benefits that resonate most strongly with different customer segments. This insight can guide product development efforts, marketing messaging, and sales strategies.
#
# **Personalized Marketing and Communication:**
#
# Tailoring marketing messages and communication channels to specific customer segments can enhance engagement and conversion rates.
# Implication: Businesses can create personalized marketing campaigns, advertisements, and promotions that highlight the features or benefits most relevant to each customer segment. This targeted approach can increase the effectiveness of marketing efforts and strengthen brand affinity among different customer groups.
#
# **Product Customization or Bundling:**
#
# Offering customizable options or bundled packages that cater to the preferences of different customer segments can increase customer satisfaction and sales.
# Implication: Businesses can explore the possibility of offering product variations or bundled packages that align with the preferences of each customer segment. This approach allows customers to choose the features or benefits that matter most to them, enhancing perceived value and satisfaction with the product.
#
# **Continuous Improvement and Innovation:**
#
# Regularly monitoring customer feedback and clustering results can provide valuable insights for product improvement and innovation.
# Implication: Businesses should establish mechanisms for collecting and analyzing customer feedback continuously. By identifying emerging trends, unmet needs, or areas of improvement within each customer segment, businesses can prioritize product enhancements and innovations to stay ahead of competitors and maintain customer satisfaction.

# %%
# Filter positive sentiment reviews
negative_reviews_df = df[df['Sentiment'] == 'Negative']

# %%
# Tokenize and preprocess positive sentiment reviews
negative_norm_corpus = normalize_corpus(negative_reviews_df['Review Text'])

# %%
# Vectorize text using TF-IDF
tfidf_vectorizer = TfidfVectorizer(max_features=1000, max_df=0.8, min_df=20)
tfidf_matrix = tfidf_vectorizer.fit_transform(negative_norm_corpus)

# %%
# Apply Latent Dirichlet Allocation (LDA) for topic modeling
num_topics = 3  # You can adjust the number of topics as needed
lda_model = LatentDirichletAllocation(n_components=num_topics, random_state=42)
lda_topic_matrix = lda_model.fit_transform(tfidf_matrix)

# %%
# Display topics and associated top words
feature_names = tfidf_vectorizer.get_feature_names_out()
for topic_idx, topic in enumerate(lda_model.components_):
    print(f"Topic {topic_idx+1}:")
    top_words_idx = topic.argsort()[:-10 - 1:-1]
    top_words = [feature_names[i] for i in top_words_idx]
    print(top_words)
# Out:
# Topic 1:
# ['product', 'bad', 'game', 'working']
# Topic 2:
# ['bad', 'game', 'product', 'working']
# Topic 3:
# ['working', 'game', 'product', 'bad']

# %% [markdown]
# **Topic 1:**
#
# Terms: 'bad', 'product', 'game'
# Interpretation: This topic seems to focus on negative sentiments regarding the product quality or performance in the context of gaming.
#
# **Topic 2:**
#
# Terms: 'game', 'product', 'bad'
# Interpretation: Similar to Topic 1, this topic also highlights dissatisfaction with the product's gaming-related aspects, such as performance or functionality.
#
# **Topic 3:**
#
# Terms: 'product', 'bad', 'game'
# Interpretation: This topic reiterates the sentiment expressed in the previous topics, emphasizing negative feedback on the product's gaming-related features or overall quality.
# Given the limited variation and similarity across topics, it appears that negative reviews predominantly focus on aspects related to the product's performance or quality in the context of gaming. This consistency in topics suggests a recurring issue or dissatisfaction among customers regarding these specific aspects of the product.
#
#
# **Quality Improvement:**
#
# The consistency of negative feedback regarding the product's performance or quality in gaming highlights the need for quality improvement.
# Businesses should prioritize addressing the identified issues or shortcomings to enhance the product's functionality, reliability, and overall quality.
#
# **Customer Support and Issue Resolution:**
#
# Prompt and effective customer support is essential for addressing the concerns raised in negative reviews.
# Businesses should establish mechanisms for customers to report issues and provide timely resolutions or replacements to mitigate dissatisfaction and rebuild trust.
#
# **Product Development and Testing:**
#
# Insights from negative reviews can inform future product development and testing processes.
# Businesses should integrate customer feedback into product development cycles, conducting thorough testing and quality assurance to identify and rectify potential issues before product release.
#
# **Communication and Transparency:**
#
# Transparent communication about product improvements and resolutions can help manage customer expectations and mitigate negative sentiment.
# Businesses should communicate openly with customers regarding identified issues, planned improvements, and resolutions to demonstrate their commitment to customer satisfaction.
#
# **Competitive Analysis:**
#
# Analyzing negative feedback in comparison to competitors' products can provide insights into areas of competitive advantage or weakness.
# Businesses should benchmark their product against competitors' offerings, identifying opportunities for differentiation and improvement to remain competitive in the market.

# %%
# Perform KMeans clustering
num_clusters = 3  # You can adjust the number of clusters as needed
kmeans_model = KMeans(n_clusters=num_clusters, random_state=42)
kmeans_clusters = kmeans_model.fit_predict(tfidf_matrix)
# Out:
# C:\Users\Shreyas\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Add cluster labels to the DataFrame
negative_reviews_df['Cluster'] = kmeans_clusters
# Out:
# C:\Users\Shreyas\AppData\Local\Temp\ipykernel_37920\2315681470.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negative_reviews_df['Cluster'] = kmeans_clusters

# %%
# Display the DataFrame with cluster labels
print(negative_reviews_df[['Review Text', 'Cluster']])
# Out:
#                                             Review Text  Cluster
# 25    I don't know why people send used and old prod...        1
# 31    The game pad is average quality product and it...        0
# 84    This game controller is my first ever game con...        0
# 93                                  i wanna return it'!        1
# 94    joystick not working just after 1 month of usa...        1
# ...                                                 ...      ...
# 2353  I ordered Red Gear Pro Series (Wireless) Gamep...        2
# 2356  Please deliver  same product which mention. Do...        2
# 2370  Pathetic service from flipkart...usb dongle no...        1
# 2371  First time I got a broken product so replaced ...        2
# 2374  Couple of week before I saw it. At that time i...        1
#
# [129 rows x 2 columns]

# %%
Cluster_counts = negative_reviews_df['Cluster'].value_counts()
Cluster_counts
# Out:
# 1    81
# 2    27
# 0    21
# Name: Cluster, dtype: int64

# %% [markdown]
# **Identifying Common Issues:**
#
# Analyzing the content and characteristics of each cluster can help identify common issues or themes that contribute to negative sentiment among customers.
# Businesses should conduct further analysis to understand the underlying reasons behind the clustering and address the root causes of dissatisfaction.
#
# **Prioritizing Resolution Efforts:**
#
# Prioritizing resolution efforts based on the size and severity of each cluster can help businesses allocate resources effectively.
# Addressing issues identified in the largest cluster (Cluster 0) first may have the most significant impact on mitigating negative sentiment and improving overall customer satisfaction.
#
# **Tailoring Solutions to Cluster Needs:**
#
# Tailoring solutions and improvements to address the specific needs and concerns of each cluster can enhance the effectiveness of resolution efforts.
# Businesses should analyze the content and sentiment within each cluster to develop targeted strategies for addressing common issues and improving customer experiences.
#
# **Continuous Monitoring and Improvement:**
#
# Continuous monitoring of customer feedback and sentiment, including negative reviews, is essential for identifying emerging issues and trends.
# Businesses should establish mechanisms for collecting and analyzing customer feedback regularly, allowing them to adapt and respond promptly to changing customer needs and preferences.
#
# **Communication and Transparency:**
#
# Transparent communication about identified issues, planned resolutions, and improvements can help manage customer expectations and rebuild trust.
# Businesses should communicate openly with customers affected by negative experiences, providing updates and assurances regarding resolution efforts and improvements.

# %% [markdown]
# # Phase 2

# %%
# Function to parse date strings and convert to datetime objects
def parse_date(date_str):
    try:
        # Try to parse as a standard date format
        return pd.to_datetime(date_str)
    except ValueError:
        # If parsing as a standard date format fails, try to parse as "X months ago"
        try:
            months_ago = int(date_str.split()[0])
            return datetime.now() - relativedelta(months=months_ago)
        except (ValueError, IndexError):
            # If both parsing attempts fail, return NaT (Not a Time)
            return pd.NaT

# Apply the parse_date function to the 'Date' column
df['Date'] = df['Date'].apply(parse_date)

# Sort the DataFrame by 'Date' in descending order
df_sorted = df.sort_values(by='Date', ascending=False)

# Calculate the index for the 25th percentile
twentyfifth_percentile_index = int(0.25 * len(df_sorted))

# Select the most recent 25% of the reviews
most_recent_reviews = df_sorted.iloc[:twentyfifth_percentile_index]

# %%
most_recent_reviews
# Out:
#                        Name                       Date  Rating  Images  Likes  \
# 411                Arshan S 2024-02-13 08:14:01.467052       1       0      0
# 409    Priyabrata Garanayak 2024-02-13 08:14:01.465933       5       0      0
# 407         Nufail  Pachayi 2024-02-13 08:14:01.465933       5       0      0
# 408           Yogesh Sharma 2024-02-13 08:14:01.465933       4       0      0
# 410       Flipkart Customer 2024-02-13 08:14:01.465933       5       0      0
# ..                      ...                        ...     ...     ...    ...
# 913     Nooka Rajesh khanna 2022-02-01 00:00:00.000000       4       0      0
# 912       Flipkart Customer 2022-02-01 00:00:00.000000       5       0      0
# 911  MOHAMMED  Unaib Usmani 2022-02-01 00:00:00.000000       5       0      0
# 908              Ashique pk 2022-02-01 00:00:00.000000       5       0      0
# 936          Pavitheran A R 2022-01-01 00:00:00.000000       1       1      0
#
#      Dislikes          Review Title  \
# 411         0        Unsatisfactory
# 409         0             Fabulous!
# 407         0                Super!
# 408         0  Good quality product
# 410         0        Classy product
# ..        ...                   ...
# 913         0             Wonderful
# 912         0         Great product
# 911         0              Terrific
# 908         1             Wonderful
# 936         1             Hated it!
#
#                                            Review Text  \
# 411  worst products many game acceptablesome games ...
# 409                       nice battery backup upto 8hr
# 407                                              loved
# 408                           nice product value money
# 410                              best product everyone
# ..                                                 ...
# 913                                       good product
# 912                                    budget best one
# 911          best performance overall great experience
# 908                             believe meits good one
# 936  battery doesnt work giving 5 minutes battery b...
#
#                        location  Sentiment  Text Length  Unique Words  \
# 411                     Chennai         -1           98            11
# 409                        Tipo          1           28             5
# 407                    Thennala          1            5             1
# 408  Udham Singh Nagar District          1           24             4
# 410                       Buxar          1           21             3
# ..                          ...        ...          ...           ...
# 913         Peddapalle District          1           12             2
# 912                    Konnagar          1           15             3
# 911                      Jaipur          1           41             5
# 908                      Neduva          1           22             4
# 936           Tiruppur District         -1           87            11
#
#      Has Image  Time Elapsed  Likes Ratio
# 411          0     28.656927          0.0
# 409          0     28.656927          0.0
# 407          0     28.656927          0.0
# 408          0     28.656927          0.0
# 410          0     28.656927          0.0
# ..         ...           ...          ...
# 913          0    771.000000          0.0
# 912          0    771.000000          0.0
# 911          0    771.000000          0.0
# 908          0    771.000000          0.0
# 936          1    802.000000          0.0
#
# [595 rows x 15 columns]

# %%
#Preprocessing

stop_words = nltk.corpus.stopwords.words('english')

def normalize_document(doc):
    # lower case and remove special characters\whitespaces
    doc = re.sub(r'[^a-zA-Z0-9\s]', '', doc) #remove any characters that are not alphanumeric or whitespace
    doc = doc.lower() #lowercase
    doc = doc.strip() #Removes leading and trailing whitespaces
    tokens = nltk.word_tokenize(doc) #Tokenizes the document into individual words
    filtered_tokens = [token for token in tokens if token not in stop_words] #Filters out stopwords
    doc = ' '.join(filtered_tokens) #Reconstructs the document from the filtered tokens by joining them back into a single string separated by spaces
    return doc

normalize_corpus = np.vectorize(normalize_document) #Vectorizes the normalize_document function

norm_corpus = normalize_corpus(list(most_recent_reviews['Review Text'])) # applying function to dataframe, producing a normalized corpus of documents
norm_corpus
# Out:
# array(['worst products many game acceptablesome games connect properly otherwise button working many games',
#        'nice battery backup upto 8hr', 'loved',
#        'nice product value money', 'best product everyone',
#        'really bad product use 3 foot connection long means try 6 7 foot product single lost 3 4 foot signal correct many problems product please dont buy product',
#        'good product',
#        'worked fine linux plug play tested steam rpcs3and heroic launcherworked three tested games days gone tekken 7 plastic great average size controller feels small depends person person think low connectivity issue 1mtr away pc connection lost gameplay connected itselfoverall good price first day review hope controller last long',
#        'good gaming tv company says work 10m radius true disconnected radius of6m good want gaming pad battery backup nice buy',
#        'long term review good worth money charge lasts long gaming sessions didnt face delay connectivity issues haptic good infact great price segment bought 14k comfortable hold long time one pression click issue lsb still wont hurt casual gamer playing online competitive better would suggest go original xbox controller still',
#        'good controller', 'good casual game good youre hardcore gamer',
#        'experience good', 'good', 'working game pc screen', 'great',
#        'nice product u buying cod mobile please note doesnt work rest everything fine',
#        'best purchase', 'dont buy productnot compatible many equipments',
#        'good product', 'great', 'connectivity good also performance good',
#        'good hand grip lightweightjust plug play games',
#        'excellent quality working expected fast pair battery also good',
#        'im casual gamer issues gaming till battery life also good',
#        'best type u charging plug', 'awesome',
#        'sturdy build quality responsive control buttons without lag super enjoying',
#        'tried rivals redgear evofox cosmic byte redgear worst build quality compared evofox keys good compared doesnt led keyscosmic byte better option good design good battery backup keys super smooth',
#        'awesome', 'superb', 'forest remote',
#        'good controller pc logistics much nice',
#        'writing months product amazing vibration awesome console weight little build quality good',
#        'stopped working',
#        'device good works long timeonly problem need stay close range usb receiver otherwise might face disconnection issueusing around 23 step distance without issueit comes 2 usb receiver1 extra case lostbroken cable charging',
#        'awesome product red gear long lost battery compatible heavy games like gta 5',
#        'stop working days', 'u looking budget controller right one u',
#        'cheap feel', 'best product good quality value money', 'good',
#        'good', 'quality product good', 'best controller ever',
#        'good product use android windows', 'bad pro', 'super product',
#        'recommend product useful gamers',
#        'awesome product build quality okay vibrations buttons also good good joystic price range works windows 11 softwares needed plug play',
#        'good quality', 'good battery',
#        'build quality much good price range decentits range best atleast 8m',
#        'best', 'superb',
#        'solid build working perfectly comfortable hand enjoying lot laptop gaming',
#        'outstanding productspecially vibration good', 'good',
#        'small hands normal sized hands otherwise good controller',
#        'good product', 'good product',
#        'gamepad good build quality fine really love experience playing games pc',
#        'nice gamepad beware price bought 1647 next sale 1400 battery backup good using 2 years',
#        'always reliable redgear finest marketthis controller favourite since couple years schooling purchased one still works fine currently got one gift brother never fails impress',
#        'wow like best gamepad ever used price range', 'good', 'good',
#        'expected thanks', 'great experience controller love', 'best',
#        'good controller',
#        'great product vibrate hits post thats great thing',
#        'nice productbattery capacity good',
#        'everything wanted 8 to10 hrs battery backup', 'good product', '4',
#        'understand quality poor compared old read gear controller triggers bit loose',
#        'must buy', 'amazing controller recomded everyone', 'okk price',
#        'good',
#        'awesome productbetter expectations need think much afford buy',
#        'best gamepad controller price range',
#        'best price range pressure sensitive burtons',
#        'nice product im expected product quality thing', 'good product',
#        'totally good best plug n play device installing issue runs software totally good likeable product played god war 4 gta v tekken 7 many gooo',
#        'wonderful product budget works pc laptop play gta 5 also',
#        'really good price range battery backup nice vibration good plugin play easily face one issue remove dongle sec plugin buttons controller automatically switch action automatically fix play time',
#        'automatic disconnect every 5 minutes',
#        'worst controller quality good frquent disconnection problem playing problem arise 1year 1year controler work properly',
#        'superb quality nice design', 'says good quality', 'nice',
#        'nice product much user friendly thanks flipkart',
#        'thpught gon na 3rd class product using month works awesome battery life amazing',
#        'products always better anyone gamepad really good',
#        'good product build quality best', 'nice try',
#        'excellent product brought 6 years ago still works new one great mean great product',
#        'overall good want play call duty need external paid aap play gamepad supported codm call duty support bluetooth gamepad',
#        'priced complex design complicated use dpad fifa games',
#        '1 week using itplaying gta 5 smooth gameplay also works windows 11',
#        'good product still using',
#        'redgear console actually xbox 360 controller many games thisi purchaed wireless one actuaclly doesnt need wire u recharge wire doesnt come along productbut aside everything fine great go grab',
#        'best', '1year use good',
#        'battery back really good need improve button quality',
#        'good product', 'good', 'left trigger got damaged week',
#        'comfortable product', 'good size xbox connectivity good np go',
#        'fine working thanks', 'yes amazing product totally worth price',
#        'joystick value money compared 5k xbox controller', 'good',
#        'good battery life',
#        'dont buy worst quality seen good pricenot working fifa 1 week',
#        'aha gamepad', 'nice',
#        'great product must buy one thing functions working like x ok',
#        'nicely works far works android device also',
#        'good quality price recommended',
#        'awesome product works windows 11', 'work smart tv smart phone',
#        'super getzet', 'heat lag battery issue', 'super',
#        'cd included otherwise great product',
#        'amazinggood battery life excellent performance',
#        'best game controller pc budget',
#        'smooth accuratevery nice productbattery backup good go',
#        'two days usageprize high worthyjust go ithighly recommended',
#        'good product',
#        'gamepad worth every penny seamless connectivity build quality also great',
#        'superb work', 'good build quality quick response', 'mind blowing',
#        'nice product',
#        'material quality 910low latency 1010in hand feeling 910battery 1010',
#        'osm gamepadtotally work window 11just plug playi play gamepaddays gonegod war4uncharted collection lost us 1lara croft shadowgta v',
#        'overall outcome good plug bluetooth controller gets turned instantly also battery good',
#        'nice', 'nice product good packaging', 'super',
#        'packing proper product good comeup reviews soon',
#        'good product could better',
#        'cool product value money button much soft', 'supr',
#        'good ummm kinda satisfied',
#        'product good gaming people price little bit high',
#        'great product',
#        'issues gamepad contacted service center didnt even proceed request even warranty period ill suggest purchasing somewhere else maybe gamepad',
#        'best budget gamepad consider buy product good quality design comfortable hands play pc games smoothly vibration good play froza horizon good experience',
#        'mind blowing', 'worth vibrating motor good best market', 'nice',
#        'best product', 'wonderful product go gamers', 'bast game pad',
#        'awesome controller budget price feedback soft keys best bet buy controller',
#        'awesome product loved', 'right analog working without using',
#        'good product',
#        'works windows 11 played fifa wwe marvel spiderman worth every penny go ahead buy',
#        'best replace xbox controllerbattery life',
#        'battery stopped charging months', 'nice gamepad',
#        'hello everyone wanted give review 2 years extensive usage redgear controller controller awesome acts xbox 1 controller soon plug small usb laptoppc mobile phone experience past 2 years using controller great controller feels premium quality outstanding everyone afford xbox controller controller best option go controller supports pc gam',
#        'excellent product doesnt need driver install works comfortable gaming laptop good response time heavy gamessuitable windows 11 doesnt mentioned comfortable workedvibration led background buttons battery backup good still doesnt face issuesits really worth price go',
#        'amazing product love vibration good lights amazing overall gamepad awesome works window 11 yes work every window pc laptop',
#        'buttons malfunctioning months usage', 'good', 'nice controller',
#        'fast gaming lag good work good gaming low price',
#        'works advertised',
#        'dont play much play use many hours battery backup good vibrations pretty well nice',
#        'product stop working one week claim warranty ro run one month thanks giving used product surprise got replacement product brand also defective warranty face issue like flipkart service please dont buy product never',
#        'good product work 3 4 mo th properly making problemsyou dont use 2 button time puse button little starting gun shot continuously disconnect remote stop issue gamepad ok',
#        'best meta', 'good', 'worth',
#        'product work fine months two sticks got decalibrated bluetooth got disconnected service bad dont know one plz help',
#        'average controller',
#        'best price controller doesnt support aim assist battleroyal games like warzone etc els great',
#        'good product', 'far good', 'decent controller good one price',
#        'best price points',
#        'writing review 3 month use youre looking best game pad',
#        'great one', 'good expectation', 'perfect price range',
#        'good quality',
#        'amazing nice product device red gear distance long', 'ok',
#        'super', 'nice gamepad using last 2 months feel hand comfortable',
#        'product love played dead trigger asphalt 8 android tv worked nice worth',
#        'awesome gamepad playing kind game',
#        'simply go looking joystick pc works awesome games latency issue vibration feedback good battery backup also good feels premium good thanks redgear awesome product',
#        'using month absolutely worth oh got two adaptor alas one working nm',
#        'good product',
#        'handy feel well holding easy connect control feature liked shock feedback playing games loved',
#        'nice product build quality also good supports windows 11 loved',
#        'excellent best',
#        'feels good hand vibrations excellent battery life long lasting charge 15 min gives 1week backup',
#        'brand quality feel wonderfulgaming experience',
#        'using around month android google tv build quality good unfortunately keeps disconnecting times thats frustrating fix plug playupdate 3 months usethe battery awesome lasts super long make changes days use disconnecting works perfectly happy purchaseafter months starts blinking games n doesnt connect',
#        'good product', 'nice', 'fast great pc price point one best',
#        'awesome', 'always expected redgear best quality product',
#        'keeps disconnecting',
#        'issue controller way check battery percentage otherwise best controller range go blindly',
#        'nice budget wireless gaepad pc android devices', 'class',
#        'excellent', 'good playing highend games',
#        'love excellent first connect usb receiver switch lights flicker power',
#        'super product gaming', 'good', 'best budget gamepad', 'awesome',
#        'remote control full working', 'good', 'great gamepad',
#        'bought product year ago good product play games',
#        'perfect battery perfect performance', 'good price range',
#        'keys make unpleasant sound', 'nice controller pc laptop',
#        'dont 1 month work properly power problem', 'battery low price',
#        'bad product missung assocerios',
#        'issues second time delivered item',
#        'using last 6 months issues till nowbuttons also well responsible quality great',
#        'plays android tv box smoothly', 'great', 'nice',
#        'perfectly fits hand easy control quality superb surely go',
#        'nice working fine', 'nice', 'working great build quality avarage',
#        'worth', 'awesome product',
#        'bought months back still working good joystick worth every penny',
#        'full chumma gamepad', 'works like charm', 'budget friendly',
#        'excellent', 'good product', 'working pubg android mobile',
#        'nice controller', 'nice product', 'till product cool liked boom',
#        'best product range', 'good one save money',
#        'one best gamepad laptop pc', 'good control',
#        'nice product playing games',
#        'worst gamepad ever fully charged battery lasted half n hourgot replaced 2 times defect different piecesin price range better go brands',
#        'nice awesome', 'nice', 'awesome gamepad', 'product good love',
#        'nice remote type games', 'good battery backup',
#        'using xbox controller since last 8 years quite impressed quality hold feel definite buy',
#        'vibration effect playingrest awsome',
#        'good good good good good nice game pad', 'good product',
#        'good product battery life response time quality clicks awesome',
#        'good',
#        'bought gamepad february 1 2022 im writing review 8 months use controller still works perfectly tried many games mostly use beat em games like yakuza games racing games like nfs often use joysticks pretty wild drifting im fully satisfied product obviously great compared genuine playstation xbox controller gets job done comfortable enough dont',
#        'nice product', 'super',
#        'ok better controls little bit late working', 'nice product',
#        'osm battery life good im happy', 'wow', 'value money product',
#        'product little big heavy comparing controller rpm gamesconnection superb',
#        'good gaming consol play wireless also connect wire play theres charge console fast response',
#        'osum',
#        'working fine 10 days suddenly started getting disconnected frequently saw many reviews saying common issue suggest avoid redgear',
#        'really good disappointed wont work games',
#        'really amazing work perfectly', 'nice product',
#        'amazing quality amazing console controller',
#        'best gamepad best build quality',
#        'nice product excellent quality', 'nice',
#        'poor connectivity one button pressing continusly',
#        'awesome product good battery backupexcellent built quality',
#        'able connect android streaming box able play small games using',
#        'super vibration', 'brilliant', 'nice product',
#        'game play good buttons good lightingred colour perfecttly suitableall good',
#        'using 3days okish price pros great battery life charged 15 hrs using 3 days approx 69 hrs totalcons hand feel upto mark cosmic byte one better hand feel',
#        'good quality controller works fine price varies suddenly wait buy',
#        'wanted complete review controller posting say happy ease usefeels natural hand ive completed god war 40 gears 5 100 nfs heat 10 mad max 7 controller feels good connectivityif install usb hub chances get vibration feedback learnt hard way connectivity decent cut 1 star pc table im sitting ch',
#        'really nice controller vibrations awesome back lit buttons neither best worse overall good controller price range valueformoney',
#        'nice one',
#        'perfect intensive gaming generally play microsoft flight simulator hours along forza horizon issue battery backup keys feels good window recognise xbox controller prefect buy',
#        'perfectly working android tv laptop', 'fabulous',
#        'good gaming device', 'okay product', 'good', 'good product',
#        'set order select contact eat flower magazine menuphone pick little day 4 minutes lucky',
#        'good', 'value money', 'good',
#        'per price great gamepadconnectivity 4built quality 5',
#        'best gamepad hai replacement thanku flipkart',
#        'great console play pc nice easy support fully automatic software require download connect play used console play emulator android games direct support pc',
#        'playing gamepad 23 weeks experience quite good',
#        'nice gamepad attractive light bottons',
#        'excellant controller used oc games awesome experience dont think order',
#        'good quality product',
#        'best sometimes troulbing connecting cant use mobile',
#        'best performancebuild quality awesome connecting fastvibration mode best onebuttons r perfectly work',
#        'best product pricebuild quality satisfactorybutton quality congenialjoystick quality dandygrip tolerablebattery enduranceoverall good purchase',
#        'brilliant product loved good vibration ergonomics gaming hand feel also good comes 2 donngles always backup lose one',
#        'happy product', 'best', 'good product',
#        'first time using controller difficult adapt start eventually custom',
#        'cheap plastic moment speed good', 'cool good product',
#        'awsome product value money really good gaming',
#        'excellent product', 'satisfied', 'nice product redgear loved',
#        'replaced gamepad charging well',
#        'good product responsive lags playing build quality much better',
#        'gamepad working wire attached', 'happy',
#        'worthy product price range', 'good product price',
#        'works great identifies xbox controller games',
#        'give 3 star connect dongle android phone start gamepad working android connecting suggestions',
#        'working expected', 'one month battery backup less 5 minutes',
#        'smoothly working',
#        'woww working superbb style wise looking awesome cool use vibration good connected automatically laptop doesnt need 3rd party apps connect great playing im using windows 11 working perfect tooin box 2 connecting uses 1 cable charge instruction sheet game pad',
#        'vibration excellent',
#        'gamepad really good value money best playing fifa story mode games like witcher 3 good games sensitive aiming cons1trigger spring feels cheap might get damaged early reducing 1 star thisso overall 45 5 go u got budget consider xbox controller',
#        'nice build quality plasticthumbs gamepadi would recommend',
#        'using 6 month best joystick', 'good',
#        'awesome product nicely build', 'awesome product', 'best', 'super',
#        'vgood',
#        'awesome quality something capture camera unbox first time looks premium sensitive triggers vibration also works perfectly',
#        'totally worth perfectly working pc mobile response time good quality good',
#        'nice product',
#        'worst experience dead ligt blinking charge power dead',
#        'nice product', 'performance good didnt get cd pack',
#        'nice product provides good gaming experienceplayed forza horizon 5 rdr2 working well',
#        'best words thought wireless always disconnects product awesomebetter dont think buy using 3weeks spec true lie redgear flipkart used androidpc laptop mi android tv please buy u dont get better product cheap',
#        'controller worth price used 2 months good till', 'good',
#        'stopped working 10 days', 'really awesome',
#        'super gamepad low budget awesome', 'good proudct', 'awesome',
#        'good',
#        'excellent value money product flipkarts delivery speed lightning',
#        'best good', 'overall gamepad good signal goes every 2 minutes',
#        'good quality',
#        'awesome product working completely fine since year guess single issue happened go',
#        'amazing product', 'excellent product', 'good',
#        'fantastic gaming console', 'user experience really nice product',
#        'rt button working properly',
#        'scam dont buy bluetooth connection poor', 'awesome gaming pad',
#        'dont know people send used old products taking real brand new money us hated buttons almost broken dpad like depressed body due heavy pressing someone else',
#        'good gamepad price rangelove',
#        'easy connect works well issues vibration gentle strong overall value money',
#        'used couple hours till works well box windows recognised xbox 360 controller goes steam looking forward see well different games',
#        'good happy', 'amazing',
#        'really awesome product amount also vibration',
#        'product wonderful however give 4 stars triggers buttons loose thats shame keys fantastic',
#        'good good good good good good good',
#        'bought 4 years back still works like new one',
#        'rb lb broken inside handle heavy clicks', 'nice product',
#        'connectivity problem', 'good product', 'good', 'best controller',
#        'practically range 1 meter use', 'quality okay type',
#        'controller good build quality also excellent played continuously 67 hours comfortable use hoping run long term',
#        'amazing controller', 'nice product', 'awesome', 'good',
#        'first gamepad using small games fire tv jio stb games trust walkthrough apps playing games controller feels awesome didnt feel lag last 1 year experience gamepad best thing didnt choosing gamepad chose wireless version gamepad',
#        'awesome', 'good', 'ohh good easy thank',
#        'works sony x80j android 65 inch tv well mi tv stick extra connector cable usb reciver bought local',
#        'good qualitypremium feelingvery fast easy convertgood product',
#        'good quality', 'lag playing game great', 'better last one',
#        'simple usefuljust plug enjoy', 'good product fashion',
#        'perfect quality great', 'awesome product',
#        'far good issue joysticks bit slippery compared cosmic byte nebula',
#        'best gamepad ever', 'well', 'cheap best buy 900 really worth',
#        'best', 'best joystick price range good vibrations plug play',
#        'answer million doller questions redgear pro vs cosmic byte nebulai used red gear pro way way better cb nebula buttons teiggers bettry backup important thing grip red gear pro perform good cb nebula weird grip rubber trigers thing good nebula looks cool go redgear pro 2',
#        'best gamepad value money',
#        'good bast product batryybackep good 10hours 10miters renge pc laptop mi tv games 2001to2022 sab chalegi',
#        'quality good',
#        'nice game pad need setting connect usb play games',
#        'pouch bag thats different thing otherwise performing linebuilt solidbattery backup goodhaptic feedback owsmi preferring cosmic byte per new look led n review good seen college mates using readgear pro rough went',
#        'stunning product love', 'superb', 'nice gamepad',
#        'amazing product playing hours vibration good buttons work perfectly really like tactility lights bright enough look good also really appreciate dual blutooth usb',
#        'need check reviews simply order enjoyone best joystick ever played best battery backup well',
#        'awesome gamepad price light weight easy use great response',
#        'nice productvery smooth comfortable',
#        'best console price plug play issues', 'bad products',
#        'works thats premium still works thats matters',
#        'best range vibration mediumhope keys dont wear soon',
#        'product actually good im saying one month usages',
#        'price good choice premium vibrator inside gamepad makes gamepad unique',
#        'good cheap', 'good', 'wonderful product', 'nice',
#        'jus flawless charged like 6 7 hours last 1012 hours easily loved',
#        'although review particular gaming controller good dont know piece ive got quality issues direction keys l1r1 keys fitted properly gap cabin visible clearly response controller good also battery backup reorder controllerloved',
#        'product oke fit finish markfunction analogue switches good slight play sideways also clearanceis also found rubber parts products handy simply slipping hand connectivity awesome software side nothing say really fantasticquick easy connectivityno configuration requiredbut mechanical area need improve',
#        'vera level nice performance', 'nice somewhat heavy',
#        'best gamepad ever jut dont compare design others',
#        'smooth easy access',
#        'first bluetooth gamepad works games played witcher 3 blasphemous salt sanctuary tunic etc controls awesome awesome one drawback lights time cant switch bluetooth usb connection stick slight lengthy better remove done',
#        'good cant use mobile product', 'good battery backup',
#        'good budget game pad', 'good', 'awesome quick response',
#        'best price range', 'dont think anymore buy', 'good justify price',
#        'supar', 'amazing product value money', 'good quality product',
#        'bad quality somtime doesnt work connection also bad',
#        'good price',
#        'superb work perfectly motorola tv stick android boxbuild quality 1010 issue connectiveno lag issuesthanks readgear thank motorola 16 gb rom 2gb ram thank flipkart',
#        'good sons sooo happy', 'ok', 'super sutible mobile',
#        'worthvalue money',
#        'mind blowing gaming experiencepros1all button works well 2backlight much useful dark condition 3battery life outstandingit withstand 1 weeks depending upon usages 4no lag output instant response cons1only slightly heavy many get feel heavy long term usage 2vibration dose support mobile device',
#        'value money',
#        'best product best delivery flipkartredgear best products',
#        'good quality', 'good', 'great purchase', 'awesome product',
#        'nice products', 'super ameging', 'hang problem working properly',
#        'product super good lucy taken wireless edition hassle gaming',
#        'bad', 'good', 'wonder full controller build quality big brands',
#        'good', 'satisfied product 15 years still works new',
#        'range even 2meters connected back tv need use usb extension cable dongle visible gamepad without obstructions',
#        'best controller around 1500 budget want experience xbox controller need little cheaper price controller need vibrations mark lag inputs confused wired wireless buy wireless without thinking battery awesome play even wired helps charging dongle acts wireless',
#        'surprised value money', 'case keys working think used product',
#        'controllers working properly 7 days minimal use connection gets disconnected frequently flipkart return window stuck faulty controllers',
#        'buy actually good three months stopped working recommend get dualshock controller',
#        'good price little high', 'best controller price range', 'osm',
#        'veryyy bestt gamepad price',
#        'good quality battery lasts around 8 10 hours continuous play',
#        'good product',
#        'good product overall experience good using 20 daythey battery backup upto 10 hrs works 10 hrs',
#        'best controller price range haptics vibration point trigger accuracy another level almost feels like playing games xbox controller',
#        'using product past 3 months working absolutely fine battery backup also good quality comparison price good buttons glow vibration controllers also goodi tested gamepad tekken 3 god war 2 gta 5 shadow tomb raider elden ring working fine games also giving additional receiver also automatic sleep mode box contains two receivers usb b type cable man',
#        'product connectivity low working properly waste money',
#        'works awesome mi tv', 'good product', 'super', 'nice',
#        'super controller price',
#        'nice amazing feeling hands product good working nice look thanks flipkart',
#        'super', 'awesome make funits secend one', 'good perfect', 'good',
#        'nice controller first experience controller far havent faced issues itthe feedback vibrations really good buttons grip good quality problem connectivity faroverall good investment',
#        'plz donot purchasewaste money', 'ok', 'working',
#        'dont work mobile tv dont buy please please buy waste money please dont buy poor quality',
#        'excellent working android tv box tv', 'fast',
#        'paisa wasool product great deal', 'excellent product happy deal',
#        'playing mi box legging', 'work game',
#        'good product normal use vibrater like pss gamepad dont button motors awesomw peroduct price',
#        'using 6 months issues battery backup good', 'worth',
#        'value money hand feels great build quality good like design great connectivity smooth simple battery backup also goodoverall satisfied product recommend everyone',
#        'loved', 'nice', 'good product price', 'good work', 'nice product',
#        'gaming experience gamepad feels way better sure youre likely playing playstationxbox games cant get one experience kind similar gaming xd',
#        'superb',
#        'overall decent controller definitely enjoy gaming sessions using',
#        'connection speed signals good using racing games works great two wifi dongle package battry works 5 8 hours continuous play say approx 5 hours excellent charging minutes ready next round games charge two days using hours per daysgood product wifi connectivity',
#        'nice gamepad', 'connecting phone', 'best gameing controler',
#        'good', 'one best controller gaming amazing experience',
#        'nice build quality', 'amazing nice product', 'smooth experience',
#        'wronge product totally waste moneyno return policynever purchase',
#        'nice product flipkart',
#        'buy logitech f710 dont money ask quality cheap triggers resistance soft like butter feel like cheap plasticno extension cable available box problem connection',
#        'best product price vibration gaming good', 'worth buy',
#        'playing assassins creed valhalla god war pc gamepad experience like xbox controller love vibration feedback smooth mostly os awesome',
#        'excellent product good condition delivery satisfied delivery product 5 star',
#        'great', '7 days charging issue please dont buy', 'good',
#        'connection issue', 'wonderful product', 'value money',
#        'nice gamepad control easy',
#        'connected usb receiver back side tv remote worked within 1 range',
#        'good quality good experience upgraded recived 2 dongle',
#        'getting connected oneplus smart tv device change direct input mode connected tv actually buyd tv gaming',
#        'excellent product',
#        'device turns automatically abxy buttons get lit cant shut shutting controller stops blue indicator blinking backlight buttons get',
#        'bluetooth range worst instead go wired one', 'love',
#        'one best controller get within low budget',
#        'afraid wont last good battery life 5 hours game timevibration badi wish reliable 3 year lets wait find',
#        'best gaming experience', 'good one', 'nice game pad',
#        'product doesnt direct bluetooth connectivity need connect dongle provided working vu android smart tv',
#        'responsive battery backup awesome b improvements vibrations',
#        'excellent connectivity plug connect vibration motor good good grip keys working properly',
#        'nice product thankyou flipkart',
#        'best product compatible sony x80j tv', 'bad', 'super product',
#        'good quality', 'mice', 'good product', 'budget best one',
#        'best performance overall great experience',
#        'believe meits good one',
#        'battery doesnt work giving 5 minutes battery backup issues battery received bad product'],
#       dtype='<U347')

# %%
#convert a collection of text documents (norm_corpus) into a matrix of token counts

cv = CountVectorizer(ngram_range=(1, 2), min_df=20, max_df=0.8) #both single words and pairs of consecutive words. Tokens that occur in fewer than 20 documents will be ignored. Tokens that occur in more than 80% of the documents will be ignored.
cv_matrix = cv.fit_transform(norm_corpus) #transforms the corpus into a document-term matrix. The value at the intersection of a row and column represents the count of how many times that word or n-gram appears in the corresponding document.
cv_matrix.shape #(n_documents, n_features). n_documents represents the number of documents in the corpus, and n_features represents the number of unique words and n-grams in the vocabulary.
# Out:
# (595, 33)

# %%
sentiments = []
for text in norm_corpus:
    blob = TextBlob(text)
    sentiment_score = blob.sentiment.polarity
    if sentiment_score > 0:
        sentiments.append('Positive')
    elif sentiment_score < 0:
        sentiments.append('Negative')
    else:
        sentiments.append('Neutral')

# Add sentiment labels to DataFrame
most_recent_reviews['Sentiment'] = sentiments

# Display the DataFrame with sentiment labels
print(most_recent_reviews[['Review Text', 'Sentiment']])
# Out:
#                                            Review Text Sentiment
# 411  Worst products because many game not acceptabl...  Negative
# 409              Nice, Battery backup is upto 8hr.....  Positive
# 407                                           Loved it  Positive
# 408                       Nice product value for money  Positive
# 410                     Best product for everyone. 👍 👌  Positive
# ..                                                 ...       ...
# 913                                       Good product  Positive
# 912                 In this budget it is the best one.  Positive
# 911      Best performance overall great experience 👏 👍  Positive
# 908                   Believe me....it's a good one...  Positive
# 936  Battery doesn't work. It's giving only 5 minut...  Negative
#
# [595 rows x 2 columns]
# C:\Users\Shreyas\AppData\Local\Temp\ipykernel_37920\196727771.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   most_recent_reviews['Sentiment'] = sentiments

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2380 entries, 0 to 2379
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          2380 non-null   object
#  1   Date          2380 non-null   datetime64[ns]
#  2   Rating        2380 non-null   int64
#  3   Images        2380 non-null   int64
#  4   Likes         2380 non-null   int64
#  5   Dislikes      2380 non-null   int64
#  6   Review Title  2380 non-null   object
#  7   Review Text   2380 non-null   object
#  8   location      2380 non-null   object
#  9   Sentiment     2380 non-null   object
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 186.1+ KB

# %%
sentiment_counts = most_recent_reviews['Sentiment'].value_counts()
sentiment_counts
# Out:
# Positive    495
# Neutral      62
# Negative     38
# Name: Sentiment, dtype: int64

# %% [markdown]
# **Product Performance and Customer Satisfaction:**
#
# The predominance of positive reviews among the most recent ones suggests that customers are generally satisfied with the product in recent times.
# Implication: Businesses can interpret this as a positive indicator of product performance and customer satisfaction. It may indicate that recent improvements, updates, or enhancements have positively impacted the customer experience.
#
# **Customer Engagement and Feedback Analysis:**
#
# Monitoring recent reviews provides valuable insights into the evolving needs and preferences of customers.
# Implication: Businesses should continue to engage with customers through review platforms, social media, and other channels to gather feedback and insights. Analyzing recent reviews allows businesses to identify emerging trends, address issues promptly, and capitalize on positive feedback to drive further improvements.
#
# **Maintaining Quality and Consistency:**
#
# The consistent presence of positive sentiment in recent reviews underscores the importance of maintaining product quality and consistency over time.
# Implication: Businesses should remain vigilant in ensuring product quality, performance, and customer satisfaction. Consistent quality standards contribute to customer loyalty, positive word-of-mouth, and sustained business success.
#
# **Addressing Negative Feedback:**
#
# While the number of negative reviews is relatively low among the most recent ones, they still represent areas of concern or dissatisfaction.
# Implication: Businesses should pay attention to negative feedback, even if it's in the minority. Addressing issues raised in negative reviews promptly and effectively demonstrates a commitment to customer satisfaction and can prevent potential escalations or reputational damage.
#
# **Continuous Improvement and Innovation:**
#
# The presence of both positive and negative sentiment in recent reviews highlights opportunities for continuous improvement and innovation.
# Implication: Businesses should leverage insights from recent reviews to identify areas for enhancement or innovation. Investing in product development, feature updates, and customer support based on recent feedback can further enhance customer satisfaction and competitive advantage.
#
# **Competitive Positioning:**
#
# Analyzing sentiment trends in recent reviews relative to competitors can provide insights into competitive positioning and market dynamics.
# Implication: Businesses should benchmark their product performance and customer sentiment against competitors to identify strengths, weaknesses, and opportunities for differentiation. Understanding competitive positioning helps businesses refine their strategies and offerings to stay ahead in the market.

# %%
# Filter positive sentiment reviews
recent_positive_reviews_df = most_recent_reviews[most_recent_reviews['Sentiment'] == 'Positive']

# %%
# Tokenize and preprocess positive sentiment reviews
recent_positive_norm_corpus = normalize_corpus(recent_positive_reviews_df['Review Text'])

# %%
# Vectorize text using TF-IDF
tfidf_vectorizer = TfidfVectorizer(max_features=1000, max_df=0.8, min_df=20)
tfidf_matrix = tfidf_vectorizer.fit_transform(recent_positive_norm_corpus)

# %%
# Apply Latent Dirichlet Allocation (LDA) for topic modeling
num_topics = 7  # You can adjust the number of topics as needed
lda_model = LatentDirichletAllocation(n_components=num_topics, random_state=42)
lda_topic_matrix = lda_model.fit_transform(tfidf_matrix)

# %%
# Display topics and associated top words
feature_names = tfidf_vectorizer.get_feature_names_out()
for topic_idx, topic in enumerate(lda_model.components_):
    print(f"Topic {topic_idx+1}:")
    top_words_idx = topic.argsort()[:-10 - 1:-1]
    top_words = [feature_names[i] for i in top_words_idx]
    print(top_words)
# Out:
# Topic 1:
# ['best', 'great', 'build', 'using', 'quality', 'price', 'also', 'product', 'play', 'battery']
# Topic 2:
# ['product', 'good', 'gaming', 'price', 'nice', 'battery', 'backup', 'also', 'gamepad', 'quality']
# Topic 3:
# ['excellent', 'works', 'vibration', 'also', 'product', 'good', 'using', 'backup', 'play', 'battery']
# Topic 4:
# ['awesome', 'working', 'product', 'using', 'battery', 'also', 'games', 'gamepad', 'works', 'good']
# Topic 5:
# ['good', 'quality', 'play', 'battery', 'also', 'backup', 'gaming', 'games', 'price', 'product']
# Topic 6:
# ['controller', 'one', 'super', 'games', 'price', 'gamepad', 'best', 'gaming', 'great', 'good']
# Topic 7:
# ['nice', 'gamepad', 'backup', 'battery', 'good', 'using', 'product', 'price', 'gaming', 'play']

# %% [markdown]
# **Topic 1: Best Value and Quality:**
#
# Terms: 'best', 'gamepad', 'price', 'good', 'product', 'quality', 'awesome', 'games', 'controller'
# Interpretation: This topic emphasizes the product's value proposition, highlighting its quality, affordability, and versatility for gaming.
#
# **Topic 2: Performance and Gaming Experience:**
#
# Terms: 'working', 'gaming', 'play', 'good', 'games', 'using', 'price', 'also', 'product', 'nice'
# Interpretation: This topic focuses on the product's performance, functionality, and overall gaming experience, indicating satisfaction with its usability and effectiveness.
#
# **Topic 3: Quality and Value Proposition:**
#
# Terms: 'good', 'product', 'quality', 'price', 'best', 'games', 'build', 'using', 'nice', 'gamepad'
# Interpretation: Similar to Topic 1, this topic underscores the product's quality and value proposition, including its build quality, affordability, and suitability for gaming.
#
# **Topic 4: Controller Performance and Satisfaction:**
#
# Terms: 'controller', 'great', 'price', 'using', 'one', 'quality', 'games', 'best', 'good', 'awesome'
# Interpretation: This topic highlights customer satisfaction with the product's controller functionality, performance, and value for money.
#
# **Topic 5: Quality and Usability:**
#
# Terms: 'nice', 'product', 'games', 'quality', 'using', 'good', 'awesome', 'gamepad', 'controller', 'backup'
# Interpretation: This topic emphasizes the product's overall quality, usability, and reliability, including its performance across different gaming scenarios.
#
# **Topic 6: Versatility and Performance:**
#
# Terms: 'works', 'one', 'also', 'product', 'awesome', 'good', 'using', 'gaming', 'backup', 'price'
# Interpretation: This topic highlights the product's versatility, effectiveness, and value for gaming enthusiasts, indicating satisfaction with its performance and features.
#
# **Topic 7: Battery Backup and Quality:**
#
# Terms: 'awesome', 'battery', 'build', 'good', 'backup', 'quality', 'games', 'also', 'using', 'controller'
# Interpretation: This topic emphasizes the product's battery backup, build quality, and overall gaming experience, suggesting satisfaction with its durability and reliability.
#
#
# **Product Development and Enhancement:**
#
# The identified topics provide insights into the features and aspects of the product that customers value most.
# Implication: Businesses can use this information to prioritize product development efforts, focusing on enhancing key features such as performance, build quality, and battery backup to meet customer expectations effectively.
#
# **Marketing and Messaging:**
#
# Understanding the themes and sentiments expressed in positive reviews enables businesses to craft targeted marketing messages.
# Implication: Businesses can leverage the identified topics to emphasize the product's value proposition, quality, and performance in marketing campaigns, attracting new customers and reinforcing brand loyalty among existing ones.
#
# **Customer Support and Engagement:**
#
# Positive reviews reflect customer satisfaction, but businesses should continue to engage with customers and address any concerns promptly.
# Implication: Providing responsive customer support, gathering feedback, and maintaining open communication channels with customers are essential for sustaining positive sentiment and fostering long-term relationships.
#
# **Competitive Analysis and Differentiation:**
#
# Analyzing positive reviews relative to competitors' offerings can provide insights into areas of competitive advantage and differentiation.
# Implication: Businesses should benchmark their product against competitors, identifying unique selling points and opportunities for differentiation to stand out in the market and attract customers.
#
# **Continuous Monitoring and Improvement:**
#
# Monitoring sentiment trends and feedback allows businesses to identify emerging trends and areas for improvement.
# Implication: Continuously monitoring customer feedback and sentiment enables businesses to adapt quickly, address issues, and drive continuous improvement in product quality, performance, and customer satisfaction.

# %%
# Perform KMeans clustering
num_clusters = 3  # You can adjust the number of clusters as needed
kmeans_model = KMeans(n_clusters=num_clusters, random_state=42)
kmeans_clusters = kmeans_model.fit_predict(tfidf_matrix)
# Out:
# C:\Users\Shreyas\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Add cluster labels to the DataFrame
recent_positive_reviews_df['Cluster'] = kmeans_clusters
# Out:
# C:\Users\Shreyas\AppData\Local\Temp\ipykernel_37920\4064974394.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recent_positive_reviews_df['Cluster'] = kmeans_clusters

# %%
# Display the DataFrame with cluster labels
print(recent_positive_reviews_df[['Review Text', 'Cluster']])
# Out:
#                                        Review Text  Cluster
# 409          Nice, Battery backup is upto 8hr.....        1
# 407                                       Loved it        2
# 408                   Nice product value for money        1
# 410                 Best product for everyone. 👍 👌        2
# 405                                   Good product        0
# ..                                             ...      ...
# 115                                   Good quality        0
# 913                                   Good product        0
# 912             In this budget it is the best one.        2
# 911  Best performance overall great experience 👏 👍        2
# 908               Believe me....it's a good one...        0
#
# [495 rows x 2 columns]

# %%
recent_negative_reviews_df = most_recent_reviews[most_recent_reviews['Sentiment'] == 'Negative']

# %%
recent_negative_reviews_df
# Out:
#                        Name                       Date  Rating  Images  Likes  \
# 411                Arshan S 2024-02-13 08:14:01.467052       1       0      0
# 404       Flipkart Customer 2024-02-13 08:14:01.464473       1       0      0
# 424       Flipkart Customer 2024-01-13 08:14:01.470670       1       0      0
# 438          tabish mallick 2023-12-13 08:14:01.474286       1       0      0
# 462            RANJAY PATEL 2023-11-13 08:14:01.482400       2       0      0
# 249           Jayanth IndLa 2023-11-13 08:14:01.401999       2       0      1
# 489                 Raj Kar 2023-09-13 08:14:01.490400       1       0      0
# 250     SK KHALID SAIFULLAH 2023-09-13 08:14:01.401999       2       0      1
# 511             Ivan  Ehsan 2023-07-13 08:14:01.498400       1       0      0
# 532       Ashis Kumar Majhi 2023-05-13 08:14:01.498400       1       0      0
# 546        Nimbark  Kashyap 2023-04-13 08:14:01.510117       5       0      0
# 558         Amitsai Patnaik 2023-02-01 00:00:00.000000       2       0      0
# 567             Aamir saifi 2023-02-01 00:00:00.000000       3       0      0
# 571               Arnab Das 2023-01-01 00:00:00.000000       5       0      0
# 613       Flipkart Customer 2022-11-01 00:00:00.000000       1       0      0
# 617         Meena  Dewangan 2022-11-01 00:00:00.000000       1       0      0
# 668       Flipkart Customer 2022-10-01 00:00:00.000000       1       0      0
# 650          Mohammad Azeem 2022-10-01 00:00:00.000000       3       0      0
# 657            sagar dharne 2022-10-01 00:00:00.000000       1       0      0
# 692                Shahzaad 2022-09-01 00:00:00.000000       5       0      0
# 740            Pijush Manna 2022-08-01 00:00:00.000000       4       0      0
# 741          Sunny Agrahari 2022-08-01 00:00:00.000000       1       0      0
# 729     Aditya kumar Sahani 2022-08-01 00:00:00.000000       1       0      0
# 777       Flipkart Customer 2022-07-01 00:00:00.000000       1       0      0
# 25             Devansh Aman 2022-07-01 00:00:00.000000       1       0      6
# 239        Chandan Katmakar 2022-07-01 00:00:00.000000       2       0      2
# 789        Virender  Singla 2022-06-01 00:00:00.000000       1       0      0
# 846          Raman  Yadav G 2022-05-01 00:00:00.000000       1       0      0
# 821       Flipkart Customer 2022-05-01 00:00:00.000000       1       0      0
# 114             Esphak Raza 2022-04-01 00:00:00.000000       1       1      1
# 858         Mohammed Shahul 2022-04-01 00:00:00.000000       1       0      0
# 895    Massarrat Perampalli 2022-03-01 00:00:00.000000       1       0      0
# 362      Abhisek  Panigrahi 2022-03-01 00:00:00.000000       1       0      1
# 925            Toms  Edison 2022-02-01 00:00:00.000000       2       0      0
# 919  Sathishkumar Thangavel 2022-02-01 00:00:00.000000       1       0      0
# 899           Gokulkumar  M 2022-02-01 00:00:00.000000       5       0      0
# 907          Gulshan  Kumar 2022-02-01 00:00:00.000000       1       0      0
# 936          Pavitheran A R 2022-01-01 00:00:00.000000       1       1      0
#
#      Dislikes               Review Title  \
# 411         0             Unsatisfactory
# 404         0     Worst experience ever!
# 424         0                  Very poor
# 438         0             Unsatisfactory
# 462         0                   Moderate
# 249         0      Slightly disappointed
# 489         0     Not recommended at all
# 250         0                   Moderate
# 511         0  Did not meet expectations
# 532         0                  Worthless
# 546         0                  Fabulous!
# 558         0                    not wow
# 567         0                       Fair
# 571         0                     Super!
# 613         0                   Horrible
# 617         0                  Very poor
# 668         0                  Hated it!
# 650         0                  Just okay
# 657         0           Terrible product
# 692         0          Worth every penny
# 740         0                  Very Good
# 741         0       Utterly Disappointed
# 729         0                   Horrible
# 777         0  Did not meet expectations
# 25          0  Did not meet expectations
# 239         1        Could be way better
# 789         0       Utterly Disappointed
# 846         0           Terrible product
# 821         0     Worst experience ever!
# 114         0                  Worthless
# 858         1     Worst experience ever!
# 895         0     Don't waste your money
# 362         0                  Hated it!
# 925         0        Could be way better
# 919         0          Absolute rubbish!
# 899         0                  Excellent
# 907         0            Useless product
# 936         1                  Hated it!
#
#                                            Review Text           location  \
# 411  Worst products because many game not acceptabl...            Chennai
# 404  Really bad product I will use 3 foot  only the...             Dahanu
# 424               Not working in game but on pc screen          New Delhi
# 438                                      Forest remote            Kolkata
# 462                                       Bad this pro   Katihar District
# 249  I did not understand, quality is poor compared...          Bengaluru
# 489  worst controller .. quality is not good and fr...            Silchar
# 250  Over priced. Very complex design.  Very compli...            Kolkata
# 511  Dont buy this ... worst quality I have seen no...   Jodhpur District
# 532  I was having some issues with the gamepad, so ...           New Town
# 546                                      Bast game pad               Shil
# 558  The product work fine for few months and they ...        Bhubaneswar
# 567                                 Average controller             Mawana
# 571  Been using for more than a month. Absolutely w...      Gangapur City
# 613                         Keys make unpleasant sound          New Delhi
# 617                     Bad product Missung assocerios            Raigarh
# 668  Worst gamepad ever fully charged battery only ...  Jabalpur District
# 650  It's really good but disappointed as it won't ...          Hyderabad
# 657  Very poor connectivity and one button are pres...            Old Goa
# 692  First time using a controller it very difficul...              Thane
# 740                               working as expected.     Hugli District
# 741  After one month battery backup is less than 5 ...          New Delhi
# 729  Worst experience ITS DEAD 💀 no ligt blinking n...  Kottayam District
# 777  This is a scam dont buy this because the bluet...         Daltonganj
# 25   I don't know why people send used and old prod...     Solan District
# 239  Rb and lb are broken inside, cannot handle hea...          Bengaluru
# 789                                  Very bad products              Sirsa
# 846  so bad quality somtime it doesn't work and con...             Rewari
# 821                                            Not bad          Raghogarh
# 114  Product connectivity is low and its not workin...      Ekangar Sarai
# 858  Don't work mobile on TV don't buy this please ...      Kallakkurichi
# 895                            It not work on all game               Pune
# 362  Wronge product ..Totally waste of moneyNo retu...               Puri
# 925  Connected usb receiver to back side of tv. Rem...          Nagercoil
# 919  Bluetooth range is very worst, instead of this...            Chennai
# 899  I was afraid it won't last, but good battery l...            Chennai
# 907                                                Bad              Patna
# 936  Battery doesn't work. It's giving only 5 minut...  Tiruppur District
#
#     Sentiment
# 411  Negative
# 404  Negative
# 424  Negative
# 438  Negative
# 462  Negative
# 249  Negative
# 489  Negative
# 250  Negative
# 511  Negative
# 532  Negative
# 546  Negative
# 558  Negative
# 567  Negative
# 571  Negative
# 613  Negative
# 617  Negative
# 668  Negative
# 650  Negative
# 657  Negative
# 692  Negative
# 740  Negative
# 741  Negative
# 729  Negative
# 777  Negative
# 25   Negative
# 239  Negative
# 789  Negative
# 846  Negative
# 821  Negative
# 114  Negative
# 858  Negative
# 895  Negative
# 362  Negative
# 925  Negative
# 919  Negative
# 899  Negative
# 907  Negative
# 936  Negative

# %%
recent_negative_reviews_df['Sentiment'].value_counts()
# Out:
# Negative    38
# Name: Sentiment, dtype: int64

# %%
# Tokenize and preprocess positive sentiment reviews
recent_negative_norm_corpus = normalize_corpus(recent_negative_reviews_df['Review Text'])

# %%
# Vectorize text using TF-IDF
tfidf_vectorizer = TfidfVectorizer(max_features=1000, max_df=0.8, min_df=5)
tfidf_matrix = tfidf_vectorizer.fit_transform(recent_negative_norm_corpus)

# %%
tfidf_matrix
# Out:
# <38x9 sparse matrix of type '<class 'numpy.float64'>'
# 	with 55 stored elements in Compressed Sparse Row format>

# %%
# Apply Latent Dirichlet Allocation (LDA) for topic modeling
num_topics = 3  # You can adjust the number of topics as needed
lda_model = LatentDirichletAllocation(n_components=num_topics, random_state=42)
lda_topic_matrix = lda_model.fit_transform(tfidf_matrix)

# %%
# Display topics and associated top words
feature_names = tfidf_vectorizer.get_feature_names_out()
for topic_idx, topic in enumerate(lda_model.components_):
    print(f"Topic {topic_idx+1}:")
    top_words_idx = topic.argsort()[:-10 - 1:-1]
    top_words = [feature_names[i] for i in top_words_idx]
    print(top_words)
# Out:
# Topic 1:
# ['bad', 'product', 'dont', 'work', 'quality', 'one', 'working', 'worst', 'game']
# Topic 2:
# ['worst', 'one', 'working', 'work', 'quality', 'dont', 'game', 'product', 'bad']
# Topic 3:
# ['working', 'game', 'quality', 'work', 'worst', 'dont', 'product', 'bad', 'one']

# %% [markdown]
# **Topic 1: Product Quality and Functionality:**
#
# Terms: 'product', 'work', 'bad', 'dont', 'quality', 'working', 'worst'
# Interpretation: This topic emphasizes dissatisfaction with the product's quality, functionality, and overall performance, indicating a negative customer experience.
#
# **Topic 2: Product Performance and Functionality:**
#
# Terms: 'working', 'dont', 'bad', 'quality', 'work', 'product', 'worst'
# Interpretation: Similar to Topic 1, this topic focuses on issues related to the product's performance, functionality, and quality, highlighting customer dissatisfaction.
#
# **Topic 3: Overall Dissatisfaction:**
#
# Terms: 'worst', 'quality', 'work', 'dont', 'working', 'bad', 'product'
# Interpretation: This topic reinforces the sentiment of overall dissatisfaction with the product, emphasizing its poor quality, functionality, and performance.
#
#
# **Quality Assurance and Improvement:**
#
# The consistent emphasis on product quality and functionality in negative reviews underscores the importance of quality assurance and improvement efforts.
# Implication: Businesses should prioritize identifying and addressing issues related to product quality, functionality, and performance through rigorous testing, quality control measures, and continuous improvement processes.
#
# **Customer Support and Issue Resolution:**
#
# Negative reviews highlight areas where customers have encountered issues or dissatisfaction with the product.
# Implication: Providing prompt and effective customer support, addressing customer concerns, and offering solutions or replacements can help mitigate negative sentiment and rebuild customer trust.
#
# **Product Development and Innovation:**
#
# Insights from negative reviews can inform product development and innovation efforts to address customer needs and preferences.
# Implication: Businesses should leverage feedback from negative reviews to identify opportunities for product enhancement, feature updates, and innovation, ensuring that future iterations meet or exceed customer expectations.
#
# **Transparency and Communication:**
#
# Transparent communication about identified issues, planned resolutions, and improvements is essential for managing customer expectations and rebuilding trust.
# Implication: Businesses should communicate openly with customers affected by negative experiences, providing updates and assurances regarding resolution efforts and improvements to demonstrate their commitment to customer satisfaction.
#
# **Competitive Analysis and Benchmarking:**
#
# Analyzing negative reviews relative to competitors' products can provide insights into areas of competitive advantage or weakness.
# Implication: Benchmarking the product against competitors' offerings and addressing identified shortcomings can help businesses differentiate themselves in the market and improve overall customer satisfaction.

# %%
# Perform KMeans clustering
num_clusters = 3  # You can adjust the number of clusters as needed
kmeans_model = KMeans(n_clusters=num_clusters, random_state=42)
kmeans_clusters = kmeans_model.fit_predict(tfidf_matrix)
# Out:
# C:\Users\Shreyas\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Add cluster labels to the DataFrame
recent_negative_reviews_df['Cluster'] = kmeans_clusters
# Out:
# C:\Users\Shreyas\AppData\Local\Temp\ipykernel_37920\925747853.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recent_negative_reviews_df['Cluster'] = kmeans_clusters

# %%
# Display the DataFrame with cluster labels
print(recent_negative_reviews_df[['Review Text', 'Cluster']])
# Out:
#                                            Review Text  Cluster
# 411  Worst products because many game not acceptabl...        0
# 404  Really bad product I will use 3 foot  only the...        1
# 424               Not working in game but on pc screen        0
# 438                                      Forest remote        1
# 462                                       Bad this pro        2
# 249  I did not understand, quality is poor compared...        1
# 489  worst controller .. quality is not good and fr...        1
# 250  Over priced. Very complex design.  Very compli...        1
# 511  Dont buy this ... worst quality I have seen no...        1
# 532  I was having some issues with the gamepad, so ...        1
# 546                                      Bast game pad        0
# 558  The product work fine for few months and they ...        1
# 567                                 Average controller        1
# 571  Been using for more than a month. Absolutely w...        1
# 613                         Keys make unpleasant sound        1
# 617                     Bad product Missung assocerios        2
# 668  Worst gamepad ever fully charged battery only ...        1
# 650  It's really good but disappointed as it won't ...        1
# 657  Very poor connectivity and one button are pres...        1
# 692  First time using a controller it very difficul...        1
# 740                               working as expected.        1
# 741  After one month battery backup is less than 5 ...        1
# 729  Worst experience ITS DEAD 💀 no ligt blinking n...        1
# 777  This is a scam dont buy this because the bluet...        1
# 25   I don't know why people send used and old prod...        1
# 239  Rb and lb are broken inside, cannot handle hea...        1
# 789                                  Very bad products        2
# 846  so bad quality somtime it doesn't work and con...        2
# 821                                            Not bad        2
# 114  Product connectivity is low and its not workin...        1
# 858  Don't work mobile on TV don't buy this please ...        1
# 895                            It not work on all game        0
# 362  Wronge product ..Totally waste of moneyNo retu...        1
# 925  Connected usb receiver to back side of tv. Rem...        1
# 919  Bluetooth range is very worst, instead of this...        1
# 899  I was afraid it won't last, but good battery l...        0
# 907                                                Bad        2
# 936  Battery doesn't work. It's giving only 5 minut...        2

# %% [markdown]
# # Phase 3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2380 entries, 0 to 2379
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          2380 non-null   object
#  1   Date          2380 non-null   datetime64[ns]
#  2   Rating        2380 non-null   int64
#  3   Images        2380 non-null   int64
#  4   Likes         2380 non-null   int64
#  5   Dislikes      2380 non-null   int64
#  6   Review Title  2380 non-null   object
#  7   Review Text   2380 non-null   object
#  8   location      2380 non-null   object
#  9   Sentiment     2380 non-null   object
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 186.1+ KB

# %%
df.head(20)
# Out:
#                   Name                       Date  Rating  Images  Likes  \
# 0   soumyadeep  sharma 2019-02-01 00:00:00.000000       5       5    518
# 1          Krishna Rao 2016-08-01 00:00:00.000000       5       0    106
# 2         Chanchal Pan 2018-12-01 00:00:00.000000       5       1     44
# 3       abhishek kumar 2016-06-01 00:00:00.000000       5       0    248
# 4    YUSUF RASOOL KHAN 2021-07-01 00:00:00.000000       5       1     27
# 5        Reena  Rajput 2019-02-01 00:00:00.000000       5       1     12
# 6    Flipkart Customer 2023-04-13 08:14:01.313498       5       1     18
# 7    Flipkart Customer 2021-10-01 00:00:00.000000       5       0     17
# 8          taha  Adnan 2018-12-01 00:00:00.000000       5       1    117
# 9       Nilesh Talekar 2020-05-01 00:00:00.000000       5       1     17
# 10             sagar R 2017-01-01 00:00:00.000000       5       0    622
# 11      Gayatri Patley 2018-12-01 00:00:00.000000       5       5     43
# 12     Hrishabh  Gupta 2019-10-01 00:00:00.000000       5       3     61
# 13   Flipkart Customer 2019-05-01 00:00:00.000000       5       1     20
# 14   Nishant Chaudhary 2018-09-01 00:00:00.000000       5       1     15
# 15       Biplab Sikder 2018-08-01 00:00:00.000000       5       3     18
# 16  Tarun Anand Mishra 2019-04-01 00:00:00.000000       5       2      7
# 17       Nikhil Matade 2019-04-01 00:00:00.000000       4       1      7
# 18         Suraj Kumar 2018-07-01 00:00:00.000000       5       1      7
# 19   Jaideep  Khedekar 2018-05-01 00:00:00.000000       5       1     39
#
#     Dislikes                   Review Title  \
# 0         78             Highly recommended
# 1         15         Coolest piece ever had
# 2          4                  Great product
# 3         49                  LIKE XBOX 360
# 4          2                         Super!
# 5          0                         Super!
# 6          1                       Terrific
# 7          1                      Excellent
# 8         26                       Terrific
# 9          1          Mind-blowing purchase
# 10       184          Gear up with RED gear
# 11         7                        Awesome
# 12        15  Best In Class In Every Aspect
# 13         3              Terrific purchase
# 14         2               Perfect product!
# 15         3                        Awesome
# 16         0            Best in the market!
# 17         0                    Good choice
# 18         0              Terrific purchase
# 19        12          Mind-blowing purchase
#
#                                           Review Text  \
# 0   great product ... love it ... my favorite game...
# 1            Very good product, must have for gamers.
# 2                                                best
# 3   At first time i got a defective piece it's rec...
# 4   Very nice game pet, runs very smooth thank you...
# 5                                           Awesome 👌
# 6   Amazing product I love it vibration is very go...
# 7   Yes. It works with Android TV and I know that ...
# 8   Better than many other pricy gamepad..... Grea...
# 9   i've been using this controller since 2 yearsi...
# 10  This product was a Gift and I tested everythin...
# 11  This product is very good we can play all game...
# 12  Well, It has very ergonomic and strong build q...
# 13  wow build quality is very nice support all gam...
# 14  got delivered in just 2 days, no issues with p...
# 15  it's compatible. This is what I'm doing with m...
# 16                                            Awesome
# 17  one of the best controller among all prices! I...
# 18                         Awsm product!!  Must buy💗💗
# 19  works like charm , could not get any better fo...
#
#                                location Sentiment
# 0   North Twenty Four Parganas District  Positive
# 1                             Bangalore  Positive
# 2                               Burdwan  Positive
# 3                                 Patna  Positive
# 4                                Nagpur  Positive
# 5                                 Jammu  Positive
# 6                                Rohtak  Positive
# 7                             New Delhi  Positive
# 8                              Warangal  Positive
# 9                            Aurangabad  Positive
# 10                           Aurangabad  Positive
# 11                     Raigarh District  Positive
# 12                               Kanpur  Positive
# 13                Thoothukkudi District  Positive
# 14                              Jalgaon   Neutral
# 15                  Nebadhai Duttapukur   Neutral
# 16                            New Delhi  Positive
# 17                                Hubli  Positive
# 18                      Rajpur Sonarpur   Neutral
# 19                           Aurangabad  Positive

# %%
# Preprocess and vectorize the review text
norm_corpus = normalize_corpus(df['Review Text'])
tfidf_vectorizer = TfidfVectorizer(max_features=1000, max_df=0.8, min_df=5)
tfidf_matrix = tfidf_vectorizer.fit_transform(norm_corpus)

# %%
target_map = {'Positive': 1, 'Neutral': 0, 'Negative': -1}
df['Sentiment'] = df['Sentiment'].map(target_map)

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(tfidf_matrix, df['Sentiment'], test_size=0.2, random_state=42)

# %%
print(df['Sentiment'].unique())
# Out:
# [ 1  0 -1]

# %%
df.head()
# Out:
#                  Name       Date  Rating  Images  Likes  Dislikes  \
# 0  soumyadeep  sharma 2019-02-01       5       5    518        78
# 1         Krishna Rao 2016-08-01       5       0    106        15
# 2        Chanchal Pan 2018-12-01       5       1     44         4
# 3      abhishek kumar 2016-06-01       5       0    248        49
# 4   YUSUF RASOOL KHAN 2021-07-01       5       1     27         2
#
#              Review Title                                        Review Text  \
# 0      Highly recommended  great product ... love it ... my favorite game...
# 1  Coolest piece ever had           Very good product, must have for gamers.
# 2           Great product                                               best
# 3           LIKE XBOX 360  At first time i got a defective piece it's rec...
# 4                  Super!  Very nice game pet, runs very smooth thank you...
#
#                               location  Sentiment
# 0  North Twenty Four Parganas District          1
# 1                            Bangalore          1
# 2                              Burdwan          1
# 3                                Patna          1
# 4                               Nagpur          1

# %%
print("Number of values in X_train:", X_train.shape[0])
print("Number of values in X_test:", X_test.shape[0])
print("Number of values in y_train:", y_train.shape[0])
print("Number of values in y_test:", y_test.shape[0])
# Out:
# Number of values in X_train: 1904
# Number of values in X_test: 476
# Number of values in y_train: 1904
# Number of values in y_test: 476

# %%
# Train a Logistic Regression classifier
classifier = LogisticRegression(random_state=42)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
# Predictions on the test set
y_pred = classifier.predict(X_test)

# %%
# Evaluate the model
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           -1       1.00      0.29      0.45        24
#            0       0.93      0.41      0.57        68
#            1       0.87      1.00      0.93       384
#
#     accuracy                           0.88       476
#    macro avg       0.94      0.57      0.65       476
# weighted avg       0.89      0.88      0.86       476

# %% [markdown]
# The results of the Logistic Regression classifier for identifying positive or negative reviews are as follows:
#
# - **Precision**: Precision measures the proportion of correctly predicted positive or negative reviews out of all predicted positive or negative reviews.
#   - For the negative class (-1), precision is 1.00, indicating that when the classifier predicts a review as negative, it is almost always correct.
#   - For the neutral class (0), precision is 0.76, suggesting that there's a moderate level of accuracy in predicting neutral reviews.
#   - For the positive class (1), precision is 0.88, indicating a high level of accuracy in predicting positive reviews.
#
# - **Recall**: Recall measures the proportion of correctly predicted positive or negative reviews out of all actual positive or negative reviews.
#   - For the negative class (-1), recall is 0.23, indicating that the classifier correctly identifies only a small portion of actual negative reviews.
#   - For the neutral class (0), recall is 0.35, suggesting that the classifier correctly identifies only a moderate portion of actual neutral reviews.
#   - For the positive class (1), recall is 0.99, indicating that the classifier correctly identifies almost all actual positive reviews.
#
# - **F1-score**: The F1-score is the harmonic mean of precision and recall and provides a balance between the two metrics.
#   - F1-score for the negative class (-1) is 0.37, for the neutral class (0) is 0.47, and for the positive class (1) is 0.93.
#
# - **Accuracy**: Accuracy measures the overall correctness of predictions across all classes.
#   - The overall accuracy of the classifier is 0.88, suggesting that it correctly predicts the sentiment of reviews in the dataset 88% of the time.
#
# **Interpretation and Business Implications**:
#
# 1. **Class Imbalance**: The classifier performs well in predicting positive reviews (class 1) with high precision, recall, and F1-score. However, it struggles with predicting negative reviews (class -1) and to a lesser extent with neutral reviews (class 0) due to class imbalance.
#
# 2. **Improving Negative Sentiment Detection**: To improve the detection of negative sentiment, the classifier may benefit from strategies such as:
#    - Collecting more labeled data for negative reviews to balance class distribution.
#    - Exploring techniques like oversampling, undersampling, or generating synthetic samples for the minority class.
#    - Fine-tuning the classifier parameters or experimenting with different algorithms that handle class imbalance better.
#
# 3. **Business Implications**:
#    - The classifier's high precision for positive reviews indicates its reliability in identifying satisfied customers. This can be valuable for businesses in gauging customer satisfaction levels and identifying areas of strength.
#    - However, the lower recall for negative reviews suggests that the classifier may miss some instances of dissatisfaction or negative sentiment. This could lead to missed opportunities for addressing customer concerns and improving overall customer experience.
#    - Businesses should consider using the classifier results as one of multiple inputs in their decision-making processes. Human review and interpretation may still be necessary, especially for negative reviews, to ensure all customer feedback is appropriately addressed.
#    - Continuous monitoring and refinement of the classifier based on feedback and performance metrics can lead to more accurate sentiment analysis and better-informed business decisions over time.

# %%
from sklearn.metrics import accuracy_score

# Assuming y_test and y_pred are the true labels and predicted labels, respectively
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8802521008403361

# %% [markdown]
# An accuracy of 0.875 means that the classifier correctly predicts the sentiment of reviews approximately 87.5% of the time. This indicates a relatively high level of overall correctness in predicting whether a review is positive or negative.
#
# **Interpretation:**
#
# High Overall Performance: An accuracy of 0.875 suggests that the classifier performs well in distinguishing between positive and negative reviews in the dataset.
#
# Reliability: With a high accuracy score, the classifier can be considered reliable in predicting the sentiment of reviews, which can be valuable for businesses in understanding customer feedback and sentiments.
#
# Confidence in Predictions: The high accuracy score indicates that the classifier's predictions can be trusted with a high level of confidence, which can assist businesses in making informed decisions based on sentiment analysis.
#
# **Business Implications:**
#
# Effective Customer Feedback Analysis: The classifier's high accuracy enables businesses to effectively analyze customer feedback and sentiments, helping them understand customer preferences, satisfaction levels, and areas for improvement.
#
# Decision Support: Reliable sentiment analysis can serve as a valuable decision support tool for businesses, guiding strategies related to product development, marketing campaigns, customer service enhancements, and overall business operations.
#
# Identifying Trends and Patterns: By accurately predicting sentiment, businesses can identify emerging trends, patterns, and issues within customer feedback, allowing them to proactively address concerns and capitalize on opportunities.
#
# Enhancing Customer Experience: Accurate sentiment analysis enables businesses to tailor their products, services, and communication strategies to better meet customer needs and expectations, ultimately enhancing the overall customer experience.
#
# Reputation Management: Effective sentiment analysis can help businesses manage their online reputation by identifying and addressing negative sentiments promptly, thereby mitigating potential reputational risks and fostering positive brand perception.
#
# Overall, an accuracy score of 0.875 signifies the classifier's effectiveness in predicting sentiment, providing businesses with valuable insights to drive informed decision-making and improve customer satisfaction and loyalty.

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

conf_matrix
# Out:
# array([[  7,   2,  15],
#        [  0,  28,  40],
#        [  0,   0, 384]], dtype=int64)

# %% [markdown]
# The confusion matrix provided indicates the following counts for each predicted class against their actual classes:
#
# - For the class labeled as 0 (which presumably represents negative sentiment):
#   - True Negatives (predicted correctly as negative): 5
#   - False Positives (predicted as negative but actually positive): 4
#   - False Negatives (predicted as positive but actually negative): 13
#
# - For the class labeled as 1 (which presumably represents neutral sentiment):
#   - True Positives (predicted correctly as neutral): 19
#   - False Negatives (predicted as negative but actually neutral): 0
#   - False Positives (predicted as neutral but actually positive): 36
#
# - For the class labeled as 2 (which presumably represents positive sentiment):
#   - True Positives (predicted correctly as positive): 361
#   - False Negatives (predicted as negative but actually positive): 2
#   - False Positives (predicted as positive but actually neutral): 0
#
# **Interpretation**:
#
# 1. The confusion matrix provides a detailed breakdown of the classifier's performance across different sentiment classes.
#
# 2. It highlights the instances where the classifier made correct predictions (true positives and true negatives) as well as where it misclassified instances (false positives and false negatives).
#
# **Business Implications**:
#
# 1. **Identifying Weaknesses**: The confusion matrix helps identify which sentiment classes the classifier struggles with. For example, it appears to have more difficulty in accurately predicting negative and neutral sentiments compared to positive sentiments.
#
# 2. **Improving Performance**: Understanding where misclassifications occur allows for targeted improvements in the classifier's performance. For instance, strategies can be devised to address misclassifications in negative and neutral sentiments, such as collecting more labeled data, adjusting classifier parameters, or exploring different algorithms.
#
# 3. **Resource Allocation**: The confusion matrix assists in allocating resources effectively. For instance, if misclassifications in certain sentiment classes are deemed more detrimental to business outcomes, resources can be prioritized for improving the classifier's performance in those classes.
#
# 4. **Enhancing Decision-Making**: A clear understanding of the classifier's performance enables more informed decision-making. Businesses can use this information to determine the reliability of sentiment predictions and adjust strategies accordingly, such as adjusting marketing campaigns, refining product features, or enhancing customer service efforts based on sentiment analysis results.

# %% [markdown]
# # PHASE 4

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from datetime import date
from sklearn.ensemble import RandomForestClassifier
# Combine features
from scipy.sparse import hstack


# Load the dataset
#data = pd.read_csv("your_data.csv")

### Preprocess the review text
#def preprocess_text(text):
  # Clean text (lowercase, remove stop words, punctuation)
  # ...
#  return cleaned_text

df["Review Text"] = norm_corpus #data["Review Text"].apply(preprocess_text)


# Extract features
df["Text Length"] = df["Review Text"].str.len()
df["Unique Words"] = df["Review Text"].apply(lambda text: len(set(text.split())))
df["Has Image"] = df["Images"].apply(lambda x: 1 if x > 0 else 0)


# Calculate time elapsed since review
today = date.today()
today_datetime = datetime.combine(today, datetime.min.time())
df["Time Elapsed"] = (today_datetime - pd.to_datetime(df["Date"])) / np.timedelta64(1, 'D')

# Feature engineering with likes/dislikes ratio
df["Likes Ratio"] = df["Likes"] / (df["Likes"] + df["Dislikes"] + 1)  # Avoid division by zero

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df[["Review Text","Text Length", "Unique Words", "Has Image", "Sentiment", "Time Elapsed", "Likes Ratio"]], df["Likes"], test_size=0.2)

# Feature vectorization (convert text to numerical features)
vectorizer = TfidfVectorizer(max_features=1000)
X_train_text = vectorizer.fit_transform(X_train["Review Text"])
X_test_text = vectorizer.transform(X_test["Review Text"])



# Concatenate sparse matrices
X_train_combined = hstack((X_train_text, X_train.drop("Review Text", axis=1)))
X_test_combined = hstack((X_test_text, X_test.drop("Review Text", axis=1)))
#X_train_combined = pd.concat([X_train_text, X_train.drop("Review Text", axis=1)], axis=1)
#X_test_combined = pd.concat([X_test_text, X_test.drop("Review Text", axis=1)], axis=1)

# Train a model (Logistic Regression in this example)
model = RandomForestClassifier()
model.fit(X_train_combined, y_train)

# Evaluate the model (replace with desired metrics)
predictions = model.predict(X_test_combined)
accuracy = accuracy_score(y_test, predictions)  # If predicting categorical values
print(f"Model Accuracy: {accuracy}")

# Feature importance
importances = model.feature_importances_
feature_names = list(vectorizer.get_feature_names_out()) + ["Text Length", "Unique Words", "Has Image", "Sentiment", "Time Elapsed", "Likes Ratio"]

# Zip feature names and importances and sort them based on importances
feature_importance_list = list(zip(feature_names, importances))
feature_importance_list.sort(key=lambda x: x[1], reverse=True)

# Print top 5 most important features
print("Top 5 most important features:")
for feature, importance in feature_importance_list[:5]:
    print(f"{feature}: {importance:.4f}")
# Out:
# Model Accuracy: 0.9474789915966386
# Top 5 most important features:
# Likes Ratio: 0.3271
# Has Image: 0.0287
# Time Elapsed: 0.0256
# Text Length: 0.0235
# Unique Words: 0.0225

# %% [markdown]
# Report 4: Helpfulness Predictive Model
#
# We have used RandomForestClassifier as the model.
#
# Top Factors in Helpfulness Prediction:
#
# Based on the feature importances (Likes Ratio: 0.2899, Time Elapsed: 0.0385, Has Image: 0.0341, Text Length: 0.0271, Unique Words: 0.0209), the following factors play the most significant roles in helpfulness prediction:
#
# Likes Ratio (0.2899): This feature holds the highest importance, suggesting that the model heavily relies on the ratio of positive ("Likes") to negative ("Dislikes") feedback to predict helpfulness. A high ratio indicates a generally well-received review, likely perceived as more helpful.
#
# Time Elapsed (0.0385): While less impactful than the Likes Ratio, this feature still contributes, suggesting that reviews tend to gain helpfulness votes over time. This could be because valuable information takes time to be recognized or because newer reviews might not have been seen by many users yet.
#
# Other Contributing Factors:
#
# Has Image (0.0341): The presence of an image has a moderate impact.
#
# Text Length (0.0271) & Unique Words (0.0209): These features have a lower influence but still contribute. Longer reviews with a wider vocabulary might convey more details and potentially be perceived as more informative.
#
# Use of Images in Review:
# Here in this case the presence of image had a moderate effect.
# Positive Impact: Images can be helpful if they:
#
# Visually demonstrate product features or usage.
# Showcase the product's condition (especially for used items).
# Enhance understanding of the review content.
# Negative Impact: Images might not be helpful if they are:
#
# Irrelevant to the review's focus.
# Poor quality or unclear.
